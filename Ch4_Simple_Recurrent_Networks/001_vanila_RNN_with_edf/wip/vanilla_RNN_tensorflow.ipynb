# %%
import numpy as np
import tensorflow as tf
from time import time
import pickle
import os
from pprint import pprint
from tqdm import tqdm
from termcolor import cprint

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# hyperparameters
HIDDEN_SIZE = 25  # size of hidden layer of neurons
SEQ_LENGTH = 125  # number of steps to unroll the RNN for
ETA = 1e-1

# %%
# data I/O
data = open('input.txt', 'r').read()  # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has {} characters, {} unique.'.format(data_size, vocab_size))
char_to_ix = {ch: i for i, ch in enumerate(chars)}
ix_to_char = {i: ch for i, ch in enumerate(chars)}
# Out:
# data has 1115394 characters, 65 unique.

# %%
char_inds = np.array(list(map(lambda char: char_to_ix[char], data)))
tail = len(data) % SEQ_LENGTH
pad_length = SEQ_LENGTH - tail if tail else 0;

# %%
batched_data = np.append(char_inds, np.zeros(pad_length), axis=0)
batched_data.resize((int(len(data)/SEQ_LENGTH), SEQ_LENGTH))
# assert batched_data.shape == (44615, 25)

# %%
def one_hot(N, x):
    
    shape = x.shape
    x.resize(x.size)
    encoded = np.zeros([x.size, N])
    
    for i in range(x.size):
        encoded[i, int(x[i])] = 1
    
    encoded.resize(list(shape) + [N])
    x.resize(shape)
    # print(shape)
    return encoded

# tests:
encoded = one_hot(65, batched_data)
# assert encoded.shape == (44615, 25, 65), "shape is incorrect"
one_hot(5, np.array([3]))
# Out:
# array([[ 0.,  0.,  0.,  1.,  0.]])

# %%
encoded = one_hot(65, batched_data)
plt.imshow(np.argmax(encoded, axis=2), aspect='auto')
plt.show()

# %%
with tf.Graph().as_default() as g, tf.Session() as sess:
    # Network definition
    x = tf.placeholder()
    y = tf.placeholder()
    h = tf.placeholder()
    
    Wxh = tf.Variable(tf.zeros((vocab_size, HIDDEN_SIZE)), initializer=tf.nn.xavier)
    Whh = tf.Variable(tf.zeros((HIDDEN_SIZE, HIDDEN_SIZE)), initializer=tf.nn.xavier)
    bh = tf.Variable(tf.zeros((HIDDEN_SIZE)))
    Why = tf.Variable(tf.zeros((HIDDEN_SIZE, vocab_size)), initializer=tf.nn.xavier)
    by = tf.Variable(tf.zeros((vocab_size)))

# %% [markdown]
# minimum forward and backward computation example with the operators.

# %%
# single input, no batching.

def build_network(inputs, targets, h0):
    # clear edf.component graph
    edf.components = []
    
    # h and y are just plain python arrays
    input_len = inputs.shape[0]

    h = [h0] + [None]*input_len
    y = [None]*input_len
    
    loss = edf.Value(0)
    
    # unfold the forward passage
    for t in range(input_len):
        
        current_char = edf.Value(inputs[t])
        
        # print(ix_to_char[np.argmax(inputs[t])])
        
        h[t + 1] = edf.Sigmoid(
            edf.Add(
                edf.VDot(
                    edf.Add(
                        edf.VDot(
                            edf.Value(inputs[t])
                            , Wxh
                        )
                        , h[t]
                    )
                    , Whh
                )
                , bh
            )
        )

        y[t] = edf.Sigmoid(
            edf.Add(
                edf.VDot(
                    h[t + 1]
                    , Why
                )
                , by
            )
        )
        # find prediction before calculating score.
        # a better way is to compute score with the confidence level
        # in mind.
        
        pred = edf.SoftMax(y[t])
        log = edf.Log(edf.ArgMax(edf.Mul(pred, current_char))) # always over axis=-1
        
        loss = edf.Add(loss, edf.Mul(log, edf.Value(-1)))
        
    return y, loss, h

# %%
np.max(batched_data)
# Out:
# 64.0

# %%
h0 = edf.Value(np.random.randn(HIDDEN_SIZE))
losses = []

for batch in batched_data[:200]:
    # print(batch)
    inputs = one_hot(vocab_size, batch)
    
    y, loss, h = build_network(inputs, inputs, h0)
    edf.Forward()
    
    h0 = edf.Value(h[-1].value)
    edf.Backward(loss)
    output = "".join(list(map(lambda pred: ix_to_char[np.argmax(pred.value)], y)
        ))    
    print(output)
    # print('loss is {}'.format(loss.value))
    losses.append(loss.value)
    edf.Adam(1e-8)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-8e85265f3506> in <module>()
#       6     inputs = one_hot(vocab_size, batch)
#       7
# ----> 8     y, loss, h = build_network(inputs, inputs, h0)
#       9     edf.Forward()
#      10
#
# <ipython-input-22-7097cc6a2248> in build_network(inputs, targets, h0)
#      50
#      51         pred = edf.SoftMax(y[t])
# ---> 52         log = edf.Log(edf.ArgMax(edf.Mul(pred, current_char))) # always over axis=-1
#      53
#      54         loss = edf.Add(loss, edf.Mul(log, edf.Value(-1)))
#
# /Users/ge/projects/deep_learning_notes/Ch4_Simple_Recurrent_Networks/vanila_RNN_with_edf/edf.py in __init__(self, x)
#     175         components.append(self)
#     176         self.x = x
# --> 177         self.grad = None if x.grad is None else DT(0)
#     178
#     179     def forward(self):
#
# AttributeError: 'ArgMax' object has no attribute 'grad'

# %%
plt.plot(losses)

# %%
for c in edf.components:
    if hasattr(c, 'y') and c.y and c.x:
        if c.x.value.shape == (100,) and c.grad.shape == (65,):
            print(c)
            print("x", c.x.value.shape)
            print("y", c.y.value.shape)
            print("del", c.grad.shape)
