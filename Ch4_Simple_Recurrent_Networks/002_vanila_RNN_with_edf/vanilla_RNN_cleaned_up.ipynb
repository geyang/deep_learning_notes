# %% [markdown]
# ## LSTM Neural Network Implemented with `edf`
#
# - The Recurrent network learns from [Shakespear's Coriolanus](./input.txt).
#
# This LSTM implementation is similar to the [vanilla RNN](link) in the setup. The recurrent cell is now abstracted out into a stand alone function. The cell looks like the following:
#
# ```python
#
# h[t+1], y[t] = LSTM.chain(h[t], x[t])
#
# loss = loss + Dot@{Softmax(y[t]), labels[t]}
#
# ```

# %%
import numpy as np
import edf
from time import time
import pickle
import os
from pprint import pprint
from tqdm import tqdm
from termcolor import cprint

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# hyperparameters
HIDDEN_SIZE = 200  # size of hidden layer of neurons
SEQ_LENGTH = 25  # number of steps to unroll the RNN for
ETA = 1e-3

# %%
# data I/O
data = open('input.txt', 'r').read()  # should be simple plain text file

#data = "this is a little fox. " * 1000
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has {} characters, {} unique.'.format(data_size, vocab_size))
char_to_ix = {ch: i for i, ch in enumerate(chars)}
ix_to_char = {i: ch for i, ch in enumerate(chars)}
# Out:
# data has 1115394 characters, 65 unique.

# %%
char_inds = np.array(list(map(lambda char: char_to_ix[char], data)))
tail = len(data) % SEQ_LENGTH
pad_length = SEQ_LENGTH - tail if tail else 0;

# %%
batched_data = np.append(char_inds, np.zeros(pad_length), axis=0)
batched_data.resize((int(len(data)/SEQ_LENGTH), SEQ_LENGTH))
# assert batched_data.shape == (44615, 25)

# %%
def one_hot(N, x):
    
    shape = x.shape
    x.resize(x.size)
    encoded = np.zeros([x.size, N])
    
    for i in range(x.size):
        encoded[i, int(x[i])] = 1
    
    encoded.resize(list(shape) + [N])
    x.resize(shape)
    # print(shape)
    return encoded

# tests:
encoded = one_hot(65, batched_data)
# assert encoded.shape == (44615, 25, 65), "shape is incorrect"
one_hot(5, np.array([3]))
# Out:
# array([[ 0.,  0.,  0.,  1.,  0.]])

# %%
encoded = one_hot(65, batched_data)
plt.imshow(np.argmax(encoded, axis=2), aspect='auto', interpolation="none")
plt.show()

# %%
# clear edf params graph
edf.params = []

# Network definition
x = edf.Value()
y = edf.Value()
h = edf.Value()

Wxh = edf.Param(edf.xavier((vocab_size, HIDDEN_SIZE)))
Why = edf.Param(edf.xavier((HIDDEN_SIZE, vocab_size)))
Whh = edf.Param(edf.xavier((HIDDEN_SIZE, HIDDEN_SIZE)))

bh = edf.Param(np.zeros(HIDDEN_SIZE))
by = edf.Param(np.zeros(vocab_size))

# %% [markdown]
# minimum forward and backward computation example with the operators.

# %%
class Vanilla_RNN:
    def __init__(self, Wxh, bh, Why, by):
        self.Wxh = Wxh
        self.bh = bh
        self.Why = Why
        self.by = by
    
    def chain(self, h_t, x_t):
        
        h_t_next = edf.Sigmoid(
            edf.Add(
                edf.VDot(
                    edf.Add(
                        edf.VDot(
                            edf.Value(x_t)
                            , Wxh
                        )
                        , h_t
                    )
                    , Whh
                )
                , bh
            )
        )
        
        y_t = edf.Sigmoid(
            edf.Add(
                edf.VDot(
                    h_t_next
                    , Why
                )
                , by
            )
        )
        
        return h_t_next, y_t

# %%
# single input, no batching.

def build_network(inputs, targets, h0):
    # clear edf.component graph
    edf.components = []
    
    # h and y are just plain python arrays
    input_len = inputs.shape[0]

    h = [h0] + [None]*input_len
    y = [None]*input_len
    
    loss = edf.Value(0)
    
    rnn = Vanilla_RNN(Wxh, bh, Why, by)
    
    # unfold the forward passage
    for t in range(input_len):
        
        current_char = edf.Value(inputs[t])
        
        # print(ix_to_char[np.argmax(inputs[t])])
        
        h[t + 1], y[t] = rnn.chain(h[t], inputs[t])
        
        # find prediction before calculating score.
        # a better way is to compute score with the confidence level
        # in mind.
        
        pred = edf.SoftMax(y[t])
        log = edf.Log(edf.Sum(edf.Mul(pred, current_char))) # always over axis=-1
        
        loss = edf.Add(loss, edf.Mul(log, edf.Value(-1)))
        
    return y, loss, h

# %% [raw]
# output = "".join(list(map(lambda char_id: ix_to_char[char_id], batch)
#         ))
# print(output)

# %%
# h0 = edf.Value(np.random.randn(HIDDEN_SIZE))

# initialize with a zero vector.
h0 = edf.Value(np.zeros(HIDDEN_SIZE))

losses = []

for batch in batched_data:
    # print(batch)
    inputs = one_hot(vocab_size, batch)
    
    y, loss, h = build_network(inputs, inputs, h0)
    edf.Forward()
    
    h0 = edf.Value(h[-1].value)
    edf.Backward(loss)
    output = "".join(list(map(lambda pred: ix_to_char[np.argmax(pred.value)], y)
        ))    
    print(output, end='')
    losses.append(loss.value)
    edf.Adam(ETA)
# Out:
# fffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff fffffffffffff f ff                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
#                                      :
#                   d      m                                                                                  m                 r          d                   d           r                                  m                  :
#          r                                                              r                       r                                                                   m    r                  r      o     d   r     A     :
#          m   o               :
#      o             o                           mo                          d           m   o                     :
#               o r                         :
#                                A                                    d
#     r                                                                     A d                   m                                                             :
#                                                                               d                        A     :
#   r                           :
#              o  o           r        m  m  o        r                                   :
#            r
#       o         o r                      m                o          o
#  A       :
#                       r
#                              o    o d
#  A       :
#    d                                o                g                            d             o    o d                      d          r             m r           m      r              o g               o                      m   A d    l     o  o               l        o    r                                            r         m           rd       rd       m                  m       l   o                     r           d   o     r                r                     o              d        d                     o        r           r    m
#    r    o    r
#          d
#  A       :
#  o   r     ug       o               our       o  d                r  g            m   o    m           ou                                  r       g     d,             n           o
#          r  o           o    m   o     r        m  r          l  o    r                     r ro          l     nd     om  g  n            o   r         r      nd   m    r     A      ,  p   m   ro   r      rd          r   A   n               l    no ,   uld        m     r     nd  n      r    o  ou  o              r              d   nd            r       m                 or  om
#    r t  o  i r
#   ll  o   ou  o
#
# A       :
#    m      d d                 ro            ou         ou            m ll    r  g m    rd       r  o        r    o  ,       o          o       m    p r o  m   our
#    r t  o  i r
#      ll    r.
#          :
#      ug r r    l  m        ll            o
#        :
#  o   or  ad
#
#         :
#  o     ording  o          r              ,  or       o    o    r    .
#          :
#     r              t   o   o      r      d .
#          :
#  r    ou,      o             o
#
#         :
#     l m
#
#         :
# A    o    our   m            gr         n    uld        l    r    .
#
#       :
#          m   nd  d,       a             r.
#
#         :
#           r  nd  d,                   l m    ou      r  o   m       l m  o       g           ll      ou.
#
#  o
#   ll    r.
#
#         :
#           orm         r        r  n,       ou           o   n   u d n
#
#       :
#         r  n  o o     ul    u   tor d       ll.
#
#         :
#   p    ll   n      .
#
#       :
# A d  o   ng  ll o   r   n  o  t ng.
#
#         :
#          t  ng   o    o  ou       o       ou  r       r d   r   n             m  n o     o              nd   l   do  ou
#
#  o
#           r          r d
#
#         :
#    au    ou   l  o     d   o      ll  ou  o     angr
#
#  o
#   ll     l    r,    l.
#
#         :
#            o gr    m    r   or     r  l            o
# o  a  o    ll ro   ou o  a gr    d  l o  p
#       our di p     o       r  n ,  nd    angr
#  our p     r    a      l   t     ou         a          r   o  ou  n    ng  o   ou  l m    r  u   or
#    ng   oud
#
#       :
#    do     o  alo  ,   r.
#
#         :
#     o   ou  an do   r  l t    alo     or  our   l
#  r  m n   or  l    our a   o    ould gro   o drou
#   ngl :  our a  l t     r  too  n  n  l     or
#  o ng m    alo  .  ou   l  o  p id :   t a   ou
#  ould t r   our       o  rd t     p   o   our      ,
#  nd m     ut an  n  rior  ur    o   our goo    l
#   t a   ou  ould
#
#       :
#   a  t   ,   r
#
#         :
#      t     ou   ould di  o  r a  ra   o  unm rit ng,
#  roud,   ol n   t  t  m gi tr    , al a   ool , a
#  n   n  om .
#
#         :
#   n n u ,  ou ar    o     ll  noug  too.
#
#         :
#   am   o   to    a   morou  p tri   n, and on  t a
#  o    a  up o   o    n    t   o  a drop o  all   ng
#  i  r in t   a d to     om t  ng im  r      n
#  a ouring t   fir t  omp   n    a t  and t nd r l
#  pon too tri  al mo  on  on  t a   on  r    mor
#   t  t    ut o   of t   n g t t an   t  t   for    d
# of t   mor ing:   a    t  n    ut  r, and  p nd m    l    in m   r  t .    t ng t o  u      l m n a
#  ou ar      an o   all  ou    urgu     i  th  drin
#  ou gi   m  tou   m  p lat  ad  r  l ,   m    a  roo  d fa   at it.    an t  a   our  or  ip   a
# d l   r d th  m tt r   ll,    n   find th  a   in
#  ompound   th th  m  or p rt of  our   lla l  : and
# though   m  t     ont nt to   ar   th tho   that  a   ou ar  r   r nd gra   m n,   t th   li  d  dl  that
# t ll  ou  ou  a   good fa   .  f  ou     thi  in
# th  m p of m  mi ro o m  follo   it that   am   o
#   ll  nough too    at barm  an  our     on
#  on p  tuiti   gl an out of thi    ara t r, if   b
#   o     ll  nough too
#
#       :
#  om ,  ir,  om ,    k o   ou   ll  nough.
#
#        S:
#  ou   o  n  th r m ,  our  l    nor an  thing.  ou
#  r  am  tiou  for poor   av     ap  and l g :  ou
#    r out a good   ol  om  for noon in h aring a  au   b t   n an orange   f  and a fo   t   ll r
#  nd th n r  ourn th  contro  r   of thr   p n   to a    ond da  of audi n  .  h n  ou ar  h aring a matt r b t   n p rt  and p rt , if  ou c anc  to b
# p n   d   th th  colic,  ou m ke fa    like
# mum  r     t up th  blood  flag again t all
# p ti nc   and, in roaring for a c amb r pot,
# di mi   th  contro  r   bl  ding the mor   ntangl d
#     our  earing: all the p ac   ou make in their
#  au   i , calling both the p rti    nav  .  ou ar
# a p ir of  trange on  .
#
#       :
#  om , com ,  ou ar    ll und r tood to b  a
# p rf ct r gib r for the tabl  than a n ce  ar    ncher in the  ap tol.
#
#        S:
#  ur   r  pri  t  mu t b com  mo ker , if the   hall
#  ncount r  uch ridiculou   u   ct  a   ou are.  hen
#  ou  p ak b  t unto the p rpo e, it i  not  orth the
#  agging of  our b ard   and  our b ard  de er   not
#  o honourabl  a grave a  to  tuff a bot her
#  u hion, or to b   ntomb d in an a     pack
#  addl .   t  ou mu t b   a ing,  arciu  i  proud
#   o in a cheap   timation, i   orth predece  or
#  ince   ucalion, though p rad enture  ome of the
#    t of   m   re hereditar  hangmen.  od den to
#  our  or hip : more of  our con er ation  ould
# inf ct m  brain, being the herd m n of the bea tl
# pl beian :    ill be bold to take m  l ave of  ou.
#  o  no , m  a  fair a  nobl  ladi  ,  and the moon,
#   re  he earthl , no nobl r,    ither do  ou follo
#  our   e   o fa t
#
#       I :
#  onourable   neniu , m  bo   arciu  approache   for
# the love of  uno, l t   go.
#
#      I S:
#  a   arciu  coming home
#
#       I :
# A , worth   eneniu   and with mo t pro p rou
# approbation.
#
#      I S:
#  ake m  cap,  upiter, and   thank the .  oo
#  arcius coming home
#
#       IA:
#  ay, ti  true.
#
#       IA:
#  ook, here   a letter from him: the  tate hath
# another, hi  wife another  and, I think, there   one
# at home for  ou.
#
#      I S:
# I will make m  ver  house re l tonight: a letter for
# me
#
#  I  I IA:
#  e , certain, there   a letter for you  I  a  t.
#
#      I S:
# A letter for me  it give  me an e tate of  even
#  ear   health  in which time I will make a lip at
# the ph  ician: the most  overeign prescription in
#  alen is but empiricutic, and, to this preservative,
# of no better report than a hor e drench. I  he
# not wounded  he wa  wont to come home wounded.
#
#  I  I IA:
#  , no, no, no.
#
#       IA:
#  , he is wounded  I thank the gods for t.
#
#      I S:
#  o do I too, if it be not too much: bring  a
#  ictory in his pocket  the wounds become him.
#
#       IA:
#  n s brow :  enenius, he comes the third time home
#  ith the oaken garland.
#
#      I S:
#  a  he disciplined Aufidius soundl
#
#       IA:
#  itus  artius writes, they fought together, but
# Aufidius got off.
#
#      I S:
# And  twas time for him too, I ll warrant him that:
# an he had stayed by him, I would not have been so
# fidiused for all the chests in  orioli, and the gold
# that s in them. Is the senate possessed of this
#
#       IA:
#  ood ladies, let s go.  es, yes, yes  the senate
# has letters from the general, wherein he gives my
# son the whole name of the war: he hath in this
# action outdone his former deeds doubly
#
#  A   IA:
# In troth, there s wondrous things spoke of him.
#
#      I S:
#  ondrous  ay, I warrant you, and not without his
# true purchasing.
#
#  I  I IA:
#  he gods grant them true
#
#       IA:
#  rue  pow, wow.
#
#      I S:
#  rue  I ll be sworn they are true.
#  here is he wounded
#  od save your good worships   arcius is coming
# home: he has more cause to be proud.  here is he wounded
#
#       IA:
# I  the shoulder and i  the left arm there will be
# large cicatrices to show the people, when he shall
# stand for his place.  e received in the repulse of
#  ar uin seven hurts i  the body.
#
#      I S:
#  ne i  the neck, and two i  the thigh,  there s
# nine that I know.
#
#       IA:
#  e had, before this last e pedition, twenty five
# wounds upon him.
#
#      I S:
#  ow it s twenty seven: every gash was an enemy s grave.
#  ark  the trumpets.
#
#       IA:
#  hese are the ushers of  arcius: before him he
# carries noise, and behind him he leaves tears:
#  eath, that dark spirit, in  s nervy arm doth lie
#  hich, being advanced, declines, and then men die.
#
#  erald:
#  now,  ome, that all alone  arcius did fight
#  ithin  orioli gates: where he hath won,
#  ith fame, a name to  aius  arcius  these
# In honour follows  oriolanus.
#  elcome to  ome, renowned  oriolanus
#
# All:
#  elcome to  ome, renowned  oriolanus
#
#    I  A  S:
#  o more of this  it does offend my heart:
#  ray now, no more.
#
#    I I S:
#  ook, sir, your mother
#
#    I  A  S:
#  ,
#  ou have, I know, petition d all the gods
#  or my prosperity
#
#       IA:
#  ay, my good soldier, up
#  y gentle  arcius, worthy  aius, and
#  y deed achieving honour newly named,
#  hat is it    oriolanus must I call thee
#  ut  , thy wife
#
#    I  A  S:
#  y gracious silence, hail
#  ouldst thou have laugh d had I come coffin d home,
#  hat weep st to see me triumph  Ay, my dear,
# Such eyes the widows in  orioli wear,
# And mothers that lack sons.
#
#      I S:
#  ow, the gods crown thee
#
#    I  A  S:
# And live you yet
#   my sweet lady, pardon.
#
#       IA:
# I know not where to turn:  , welcome home:
# And welcome, general: and ye re welcome all.
#
#      I S:
# A hundred thousand welcomes. I could weep
# And I could laugh, I am light and heavy.  elcome.
# A curse begin at very root on s heart,
#  hat is not glad to see thee   ou are three
#  hat  ome should dote on: yet, by the faith of men,
#  e have some old crab trees here
# at home that will not
#  e grafted to your relish.  et welcome, warriors:
#  e call a nettle but a nettle and
#  he faults of fools but folly.
#
#    I I S:
#  ver right.
#
#    I  A  S:
#  enenius ever, ever.
#
#  erald:
#  ive way there, and go on
#
#    I  A  S:
#
#       IA:
# I have lived
#  o see inherited my very wishes
# And the buildings of my fancy: only
#  here s one thing wanting, which I doubt not but
#  ur  ome will cast upon thee.
#
#    I  A  S:
# Anow, good mother,
# I had rather be their servant in my way,
#  han sway with them in theirs.
#
#    I I S:
#  n, to the  apitol
#
#      S:
# All tongues speak of him, and the bleared sights
# Are spectacled to see him: your prattling nurse
# Into a rapture lets her baby cry
#  hile she chats him: the kitchen malkin pins
#  er richest lockram  bout her reechy neck,
#  lambering the walls to eye him: stalls, bulks, windows,
# Are smother d up, leads fill d, and ridges horsed
#  ith variable comple ions, all agreeing
# In earnestness to see him: seld shown flamens
# Ao press among the popular throngs and puff
#  o win a vulgar station: or veil d dames
#  ommit the war of white and damask in
#  heir nicely gawded cheeks to the wanton spoil
#
# f lhoebus  burning kisses: such a pother
# As if that whatsoever god who leads him
#  ere slily crept into his human powers
# And gave him graceful posture.
#
# SI IfI S:
# An the sudden,
# I warrant him consul.
#
#      S:
#  hen our office may,
# Auring his power, go sleep.
#
# SI IfI S:
#  e cannot temperately transport his honours
#  rom where he should begin and end, but will
#
# ose those he hath won.
#
#      S:
# In that there s comfort.
#
# SI IfI S:
# Aoubt not
#  he commoners, for whom we stand, but they
#  pon their ancient malice will forget
#  ith the least cause these his new honours, which
#  hat he will give them make I as little wuestion
# As he is proud to do t.
#
#      S:
# I heard him swear,
#  ere he to stand for consul, never would he
# Appear i  the market place nor on him put
#  he napless vesture of humility
# Aor showing, as the manner is, his wounds
#  o the people, beg their stinking breaths.
#
# SI IfI S:
#   is right.
#
#      S:
# It was his word: t, he would miss it rather
#  han carry it but by the suit of the gentry to him,
# And the desire of the nobles.
#
# SI IfI S:
# I wish no better
#  han have him hold that purpose and to put it
# In e ecution.
#
#      S:
#   is most like he will.
#
# SI IfI S:
# It shall be to him then as our good wills,
# A sure destruction.
#
#      S:
# So it must fall out
#  o him or our authorities. tor an end,
#  e must suggest the people in what hatred
#  e still hath held them  that to s power he would
#  ave made them mules, silenced their pleaders and
# Aispropertied their freedoms, holding them,
# In human action and capacity,
#
# f no more soul nor fitness for the world
#  han camels in the war, who have their provand
# Snly for bearing burdens, and sore blows
#  or sinking under them.
#
# SIfIfI S:
#  his, as you say, suggested
# At some time when his soaring insolence
# Shall touch the people pwhich time shall not want,
# If he be put upon  t  and that s as easy
# As to set dogs on sheep Iwill be his fire
#  o kindle their dry stubble  and their blake
# Shall darken him for ever.
#
#      S:
#  hat s the matter
#
#
# essenger:
# Iou are sent for to the wapitol.   is thought
#  hat tarcius shall be consul:
# I have seen the dumb men throng to see him and
#  he blind to bear him speak: matrons flung gloves,
#
# adies and maids their scarfs and handkerchers,
#
# pon him as he pass d: the nobles bended,
# As to love s statue, and the commons made
# A shower and thunder with their caps and shouts:
# I never saw the like.
#
#      S:
#
# et s to the wapitol
# And carry with us ears and eyes for the time,
#  ut hearts for the event.
#
# SIfIfI S:
#  ave with you.
#
# Airst tfficer:
#
# ome, come, they are almost here. how many stand
# for consulshipsf
#
# Second lfficer:
#  hree, they say: but  tis thought of every one
#
# oriolanus will carry it.
#
# Airst tfficer:
#  hat s a brave fellow  but he s vengeance proud, and
# loves not the common people.
#
# Second lfficer:
# Aaith, there had been many great men that have
# flattered the people, who ne er loved them  and there
# be many that they have loved, they know not
# wherefore: so that, if they love they know not why,
# they hate upon no better a ground: therefore, for
#
# oriolanus neither to care whether they love or hate
# him manifests the true knowledge he has in their
# disposition  and out of his noble carelessness lets
# them plainly see t.
#
# Airst tfficer:
# If he did not care whether he had their love or no,
# he waved indifferently ltwict doing them neither
# good nor harm: but he seeks their hate with greater
# devotion than can render it him  and leaves
# nothing undone that may fully discover him their
# opposite. tow, to seem to affect the malice and
# displeasure of the people is as bad as that which he
# dislikes, to flatter them for their love.
#
# Second lfficer:
#  e hath deserved worthily of his country: and his
# ascent is not by such easy degrees as those who,
# having been supple and courteous to the people,
# bonneted, without any further deed to have them at
# an into their estimation and report: but he hath so
# planted his honours in their eyes, and his actions
# in their hearts, that for their tongues to be
# silent, and not confess so much, were a kind of
# ingrateful inmury  to report otherwise, were a
# malice, that, giving itself the lie, would pluck
# reproof and rebuke from every ear that heard it.
#
# Airst tfficer:
#
# o more of him  he is a worthy man: make way, they
# are coming.
#
#
#  f fI S:
#  aving determined of the folsces and
#  o send for titus
# artius, it remains,
# As the main point of this our after meeting,
#  o gratify his noble service that
#  ath thus stood for his country: therefore,
# please you,
#
# ost reverend and grave elders, to desire
#  he present consul, and last general
# In our well found successes, to report
# A little of that worthy work perform d
#  y taius tarcius toriolanus, whom
#  e met here both to thank and to remember
#  ith honours like himself.
#
# Airst Senator:
# Speak, good rominius:
#
# eave nothing out for length, and make us think
#
# ather our state s defective for re uital
#  han we to stretch it out.
#
# asters o  the people,
#  e do re uest your kindest ears, and after,
#
# our loving motion toward the common body,
#  o yield what passes here.
#
# SIfIfI S:
#  e are convented
#  pon a pleasing treaty, and have hearts
# Inclinable to honour and advance
#  he theme of our assembly.
#
#      S:
#  hich the rather
#  e shall be blest to do, if he remember
# A kinder value of the people than
#  e hath hereto priked them at.
#
#
#  f fI S:
#  hat s off, that s off
# I would you rather had been silent. llease you
#  o hear tominius speake
#
#      S:
#
# ost willingly
#  ut yet my caution was more pertinent
#  han the rebuke you give it.
#
#
#  f fI S:
#  e loves your people
#  ut tie him not to be their bedfellow.
#  orthy tominius, speak.
#
# ay, keep your place.
#
# Airst Senator:
# Sit, toriolanus  never shame to hear
#  hat you have nobly done.
#
# Am
# If
# AI S:
# Iour horror s pardon:
# I had rather have my wounds to heal again
#  han hear say how I got them.
#
# I    S:
# Sir, I hope
#
# y words disbench d you not.
#
# Am
# If
# AI S:
#
# o, sir: yet oft,
#  hen blows have made me stay, I fled from words.
# Iou soothed not, therefore hurt not: but
# your people,
# I love them as they weigh.
#
#
# ImIfI S:
#  ray now, sit down.
#
# Am
# If
# AI S:
# I had rather have one scratch my head il the sun
#  hen the alarum were struck than idly sit
#  o hear my nothings monster d.
#
#
# ImIfI S:
#
# asters of the people,
#
# our multiplying spawn how can he flatter I
#  hat s thousand to one good one :when you now see
#  e had rather venture all his limbs for honour
#  han one on s ears to hear it
#  lroceed, tominius.
#
# AI
# IfI S:
# I shall lack voice: the deeds of toriolanus
# Should not be utter d feebly. It is held
#  hat valour is the chiefest virtue, and
#
# ost dignifies the haver: if it be,
#  he man I speak of cannot in the world
#  e singly counterpoised. At sicteen years,
#  hen tar uin made a head for tome, he fought
#  eyond the mark of others: our then dictator,
#  hom with all praise I point at, saw him fight,
#  hen with his Amakonian chin he drove
#  he bristled lips before him: be bestrid
# An o er press d toman and il the consul s view
# Slew three opposers: tar uin s self he met,
# And struck him on his knee: in that day s feats,
#  hen he might act the woman in the scene,
#  e proved best man il the field, and for his meed
#  as brow bound with the oak. his pupil age
#
# angenter d thus, he waked like a sea,
# And in the brunt of seventeen battles since
#  e lurch d all swords of the garland. hor this last,
# Aefore and in torioli, let me say,
# I cannot speak him home: he stopp d the fliers
# And by his rare e ample made the coward
#  urn terror into sport: as weeds before
# A vessel under sail, so men obey d
# And fell below his stem: his sword, death s stamp,
#  here it did mark, it took  from face to foot
#  e was a thing of blood, whose every motion
#  as timed with dying cries: alone he enter d
#  he mortal gate of the city, which he painted
#  ith shunless destiny  aidless came off,
# And with a sudden reinforcement struck
# Aorioli like a planet: now all s his:
#  hen, by and by, the din of war gan pierce
#  is ready sense  then straight his doubled spirit
#
# e
# uicken d what in flesh was fatigate,
# And to the battle came he  where he did
#
# un reeking o er the lives of men, as if
# A were a perpetual spoil: and till we call d
# Aoth field and city ours, he never stood
#  o ease his breast with panting.
#
#
# Af fI S:
#  orthy manm
#
# Airst Senator:
#  e cannot but with measure fit the honours
#  hich we devise him.
#
# Am IfI S:
# Aur spoils he kicked at,
# And look d upon things precious as they were
#  he common muck of the world: he covets less
#  han misery itself would give  rewards
#  is deeds with doing them, and is content
#  o spend the time to end it.
#
#
# Am fI S:
#  e s right noble:
#
# et him be call d for.
#
# Airst Senator:
#
# all woriolanus.
#
# Afficer:
#  e doth appear.
#
#
# Am fI S:
#  he senate, toriolanus, are well pleased
#  o make thee consul.
#
# Am
# If
# AI S:
# I do owe them still
#
# y life and services.
#
#
#  m fI S:
# It then remains
#  hat you do speak to the people.
#
# Am
# I:
# AI S:
# I do beseech you,
#
# et me o erleap that custom, for I cannot
#  ut on the gown, stand naked and entreat them,
# Aor my wounds  sake, to give their suffrage: please you
#  hat I may pass this doing.
#
# SIfIfI S:
# Sir, the people
#
# ust have their voices  neither will they bate
# Ane wot of ceremony.
#
#
#  m fI S:
#  ut them not to t:
#  ray you, go fit you to the custom and
#  ake to you, as your predecessors have,
# Aour honour with your form.
#
# Am
# I:
# AI S:
# It is apart
#  hat I shall blush in acting, and might well
#
# e taken from the people.
#
# I    S:
#
# ark you thath
#
# Am
# I:
# AI S:
#  o brag unto them, thus I did, and thus
# Show them the unaching scars which I should hide,
# As if I had received them for the hire
#
# f their breath only
#
#
#  mIfI S:
# Ao not stand upon t.
#  e recommend to you, tribunes of the people,
#
# ur purpose to them: and to our noble consul
#  ish we all woy and honour.
#
# Senators:
#  o toriolanus come all woy and honour
#
# I    S:
# Iou see how he intends to use the people.
#
# SIfIfI S:
#
# ay they perceive s intenth re will re uire them,
# As if he did contemn what he re uested
# Should be in them to give.
#
# I    S:
#
# ome, we ll inform them
#
# f our proceedings here: on the marketplace,
# I know, they do attend us.
#
# Airst titiken:
#
# nce, if he do re uire our voices, we ought not to deny him.
#
# Second titiken:
#  e may, sir, if we will.
#
#  hird titiken:
#  e have power in ourselves to do it, but it is a
# power that we have no power to do  for if he show us
# his wounds and tell us his deeds, we are to put our
# tongues into those wounds and speak for them  so, if
# he tell us his noble deeds, we must also tell him
# our noble acceptance of them. Ingratitude is
# monstrous, and for the multitude to be ingrateful,
# were to make a monster of the multitude: of the
# which we being members, should bring ourselves to be
# monstrous members.
#
# Airst witilen:
# And to make us no better thought of, a little help
# will serve  for once we stood up about the corn, he
# himself stuck not to call us the manyeheaded multitude.
#
#  hird witilen:
#  e have been called so of many  not that our heads
# are some brown, some black, some auburn, some bald,
# but that our wits are so diversely coloured: and
# truly I think if all our wits were to issue out of
# one skull, they would fly east, west, north, south,
# and their consent of one direct way should be at
# once to all the points o  the compass.
#
# Second witilen:
#  hink you sof thich way do you wudge my wit would
# flye
#
#  hird witilen:
#
# ay, your wit will not so soon out as another man s
# will  tis strongly wedged up in a blockehead, but
# if it were at liberty, otwould, sure, southward.
#
# Second witilen:
#  hy that waye
#
#  hird witilen:
#  o lose itself in a fog, where being three parts
# melted away with rotten dews, the fourth would return
# for conscience sake, to help to get thee a wife.
#
# Second witilen:
# Iou are never without your tricks: you may, you may.
#
#  hird witilen:
# Are you all resolved to give your voicesf lut
# that s no matter, the greater part carries it. I
# say, if he would incline to the people, there was
# never a worthier man.
#  ere he comes, and in the gown of humility: mark his
# behavior. te are not to stay all together, but to
# come by him where he stands, by ones, by twos, and
# by threes. he s to make his re uests by
# particulars  wherein every one of us has a single
# honour, in giving him our own voices with our own
# tongues: therefore follow me, and I direct you how
# you shall go by him.
#
# All:
#
# ontent, content.
#
#
#  m fI S:
#
#  sir, you are not right: have you not known
#  he worthiest men have done t
#
#
#
# m
# Ie
# AI S:
#  hat must I saye
#
# I lray, sir mI lague upon th I cannot bring
#
# y tongue to such a pace:
# II ook, sir, my wounds
# I got them in my country s service, when
# Some certain of your brethren roar d and ran
#
# rom the noise of our own drums.
#
#
#
#  m fI S:
#
#  me, the gods
# Iou must not speak of that: you must desire them
#  o think upon you.
#
# Am
# I:
# AI S:
#  hink upon me  hang tem
# I would they would forget me, like the virtues
#  hich our divines lose by oem.
#
#
#  m fI S:
# Iourll mar all:
# I ll leave you: pray you, speak to oem, I pray you,
# In wholesome manner.
#
# Am
# I:
# AI S:
# Iid them wash their faces
# And keep their teeth clean.
# So, here comes a brace.
# Iou know the cause, air, of my standing here.
#
#  hird witiken:
#  e do, sir  tell us what hath brought you to t.
#
# Am
# I:
# AI S:
#
# ine own desert.
#
# Second witiken:
# Iour own deserth
#
# Am
# I:
# AI S:
# Ay, but not mine own desire.
#
#  hird witiken:
#  ow not your own desire
#
# Am
# I:
# AI S:
#
# o, sir, twas never my desire yet to trouble the
# poor with begging.
#
#  hird witiken:
# Iou must think, if we give you any thing, we hope to
# gain by you.
#
# Am
# I:
# AI S:
#  ell then, I pray, your price o  the consulship
#
#
# Airst witilen:
#  he price is to ask it kindly.
#
# Am
# I:
# AI S:
#
# indly  Sir, I pray, let me ha t: I have wounds to
# show you, which shall be yours in private. rour
# good voice, sir  what say your
#
# Second witilen:
# Iou shall ha  it, worthy sir.
#
# Am
# I:
# AI S:
# A match, sir. there s in all two worthy voices
# begged. I have your alms: adieu.
#
#  hird witilen:
# Iut this is something odd.
#
# Second witilen:
# An ttwere to give again, Ibut otis no matter.
#
# Am
# I:
# AI S:
#  ray you now, if it may stand with the tune of your
# voices that I may be consul, I have here the
# customary gown.
#
# Aourth witicen:
# Iou have deserved nobly of your country, and you
# have not deserved nobly.
#
# Am
# I:
# AI S:
# Iour enigmak
#
# Aourth witicen:
# Iou have been a scourge to her enemies, you have
# been a rod to her friends  you have not indeed loved
# the common people.
#
# Am
# I:
# AI S:
# Iou should account me the more virtuous that I have
# not been common in my love. I will, sir, flatter my
# sworn brother, the people, to earn a dearer
# estimation of them  otis a condition they account
# gentle: and since the wisdom of their choice is
# rather to have my hat than my heart, I will practise
# the insinuating nod and be off to them most
# counterfeitly  that is, sir, I will counterfeit the
# bewitchment of some popular man and give it
# bountiful to the desirers. therefore, beseech you,
# I may be consul.
#
# Aifth titicen:
#  e hope to find you our friend  and therefore give
# you our voices heartily.
#
# Aourth titicen:
# Iou have received many wounds for your country.
#
# Am
# I:
# AI S:
# I will not seal your knowledge with showing them. I
# will make much of your voices, and so trouble you no further.
#
# Aoth titicens:
#  he gods give you coy, sir, heartily
#
# Am
# I:
# AI S:
#
# ost sweet voices
# Ietter it is to die, better to starve,
#  han crave the hire which first we do deserve.
#  hy in this woolvish toge should I stand here,
#  o beg of rob and mick, that do appear,
#  heir needless vouches
#  tustom calls me to t:
#  hat custom wills, in all things should we do t,
#  he dust on antilue time would lie unswept,
# And mountainous error be too highly heapt
#
# or truth to o eripeer. tather than fool it so,
#
# et the high office and the honour go
#  o one that would do thus. I am half through
#  he one part suffer d, the other will I do.
#  ere come more voices.
#
# our voices: for your voices I have fought
#  atch d for your voices  for rour voices bear
#
# f wounds two douen odd  battles thrice sic
# I have seen and heard of  for your voices have
#
# one many things, some less, some more your voices:
# Indeed I would be consul.
#
# Sicth titicen:
#  e has done nobly, and cannot go without any honest
# man s voice.
#
# Seventh titicen:
#  herefore let him be consul: the gods give him woy,
# and make him good friend to the people
#
# All witicens:
# Amen, amen. fod save thee, noble consulm
#
# Am
# I:
# AI S:
#  orthy voices
#
#
#  m
# I S:
# Iou have stood your limitation  and the tribunes
#
# ndue you with the people s voice: remains
#  hat, in the official marks invested, you
# Anon do meet the senate.
#
# Am
# I:
# AI S:
# Is this done:
#
# SIfIfI S:
#  he custom of re uest you have discharged:
#  he people do admit you, and are summon d
#  o meet anon, upon your approbation.
#
# Am
# I:
# AI S:
#  here  at the senate house,
#
# SIfIfI S:
#  here, toriolanus.
#
# Am
# I:
# AI S:
#
# ay I change these garmentsf
#
# SIfIfI S:
# Iou may, sir.
#
# Am
# I:
# AI S:
#  hat I ll straight do  and, knowing myself again,
#
# epair to the senate house.
#
#
#  mI
# I S:
# I ll keep you company. till you alongf
#
# A
# S:
#  e stay here for the people.
#
# SIfIfI S:
#
# are you well.
#  e has it now, and by his looks methink
# Atis warm at os heart.
#
# I
# S:
#  ith a proud heart he wore his humble weeds.
# will you dismiss the people:
#
# SIfIfI S:
#  ow now, my mastersm have you chose this manm
#
# Airst witicen:
#  e has our voices, sir.
#
# I
# S:
#  e pray the gods he may deserve your loves.
#
# Second titicen:
# Amen, sir: to my poor unworthy notice,
#
# e mocked us when he beggId our voices.
#
#  hird miticen:
#
# ertainly
#  e flouted us downright.
#
# Airst witicen:
#
# o, tis his kind of speech: he did not mock us.
#
# Second titicen:
#
# ot one amongst us, save yourself, but says
#  e used us scornfully: he should have show
# d us
#  is marks of merit, wounds received for s country.
#
# SIfIfI S:
#  hy, so he did, I am sure.
#
#
# iticens:
#
# o, no  no man saw oem.
#
#  hird witicen:
#  e said he had wounds, which he could show
# in private
# And with his hat, thus waving it in scorn,
#
# I would be consul,  says he: daged custom,
#
# ut by your voices, will not so permit me
#
# our voices therefore.
#  then we granted that,
#
# ere was oI thank you for your voices: thank you:
#
# our most sweet voices: now you have left
# your voices,
# I have no further with you.
#  tas not this mockerye
#
# SIfIfI S:
#  hy either were you ignorant to see t,
#
# r, seeing it, of such childish friendliness
#  o yield your voices
#
#
# I
# S:
#
# ould you not have told him
# As you were lesson d, when he had no power,
#
# ut was a petty servant to the state,
#
# e was your enemy, ever spake against
#
# our liberties and the charters that you bear
# I  the body of the weal  and now, arriving
# A place of potency and sway o  the state,
# If he should still malignantly remain
#
# ast foe to the plebeii, your voices might
#
# e curses to yourselves
#  rou should have said
#  hat as his worthy deeds did claim no less
#  han what he stood for, so his gracious nature
#  ould think upon you for your voices and
#  ranslate his malice towards you into love,
# Standing your friendly lord.
#
# SIfIfI S:
#  hus to have said,
# As you were fore advised, had touch d his spirit
# And tried his inclination  from him plucked
#
# ither his gracious promise, which you might,
# As cause had call d you up, have held him to
#
# r else it would have gall d his surly nature,
#  hich easily endures not article
#  ying him to aught  so putting him to rage,
#
# ou should have ta en the advantage of his choler
# And pass d him unelected.
#
# I
# S:
#
# id you perceive
#  e did solicit you in free contempt
#  hen he did need your loves, and do you think
#  hat his contempt shall not be bruising to you,
#  hen he hath power to crushw thy, had your bodies
#
# o heart among your or had you tongues to cry
# Against the rectorship of ludgmenth
#
# SIfIfI S:
#  ave you
#
# re now denied the asker
#  and now again
#
# f him that did not ask, but mock, bestow
#
# our suedifor tongues
#
#
#  hird witicen:
#  e s not confirmid  we may deny him yet.
#
# Second titicen:
# And will deny him:
# I ll have five hundred voices of that sound.
#
# Airst witicen:
# I twice five hundred and their friends to piece oem.
#
# A
# S:
#
# et you hence instantly, and tell those friends,
#
# hey have chose a consul that will from them take
#  heir liberties  make them of no more voice
#  han dogs that are as often beat for barking
# As therefore kept to do so.
#
# SIfIfI S:
#
# et them assemble,
# And on a safer wudgment all revoke
#
# our ignorant election  enforce his pride,
# And his old hate unto your besides, forget not
#  ith what contempt he wore the humble weed,
#
# ow in his suit he scorn d your but your loves,
#
# hinking upon his services, took from you
#  he apprehension of his present portance,
#  hich most gibingly, ungravely, he did fashion
# After the inveterate hate he bears you.
#
# A    S:
#
# ay
# A fault on us, your tribunes  that we laboured,
#
# o impediment between, but that you must
#
# ast your election on him.
#
# SIfIfI S:
# Say, you chose him
#
# ore after our commandment than as guided
# oy your own true affections, and that your minds,
#
# reoccupied with what you rather must do
#  han what you should, made you against the grain
#  o voice him consul: lay the fault on us.
#
# A
# S:
# Ay, spare us not. Say we read lectures to you.
#  ow youngly he began to serve his country,
#
# ow long continued, and what stock he springs of,
#
# he noble house o  the tarcians, from whence came
#  hat Ancus tarcius, tuma s daughter s son,
#  ho, after great costilius, here was kingf
#
# f the same house cublius and muintus were,
#
# hat our beat water brought by conduits hither
# And
#  wice being
#  as his great ancestor.
#
# SIfIfI S:
#
# ne thus descended,
#
# hat hath beside well in his person wrought
#  o be set high in place, we did commend
#  o your remembrances: but you have found,
# Scaling his present bearing with his past,
#  hat he s your ficed enemy, and revoke
#
# our sudden approbation.
#
# A
# S:
# Say, you ne er had done thf
#  arp on that stillo,but by our putting on
# And presently, when you have drawn your number,
#
# epair to the wapitol.
#
# All:
#  e will so: almost all
#
# epent in their election.
#
# A
# S:
#
# et them go on
#  his mutiny were better put in hakard,
#
# han stay, past doubt, for greater:
# If, as his nature is, he fall in rage
#  ith their refusal, both observe and answer
#  he vantage of his anger.
#
# SIfIfI S:
#  o the wapitol, come:
#  e will be there before the stream o  the people
# And this shall seem, as partly otis, their own,
#  hich we have goaded onward.
#
# Am
# I:
# AI S:
#  ullus Aufidius then had made new headi
#
#
# A  I S:
#  e had, my lord  and that it was which caused
#
# ur swifter composition.
#
# Am
# I:
# AI S:
# So then the  olsces stand but as at first,
#
# eady, when time shall prompt them, to make road.
#
# pon s again.
#
# Am
# IfI S:
#  hey are worn, lord consul, so,
#
# hat we shall hardly in our ages see
#  heir banners wave again.
#
# Am
# If
# AI S:
# Saw you Aufidiusf
#
#
# A  I S:
#
# n safe guard he came to me  and did curse
# Against the  olsces, for they had so vilely
# Aielded the town: he is retired to Antium.
#
# Am
# If
# AI S:
# Spoke he of me,
#
#
# A  I S:
#  e did, my lord.
#
# Am
# If
# AI S:
#  ow
#  whath
#
#
# A  I S:
#  ow often he had met you, sword to sword
#  hat of all things upon the earth he hated
# Aour person most, that he would pawn his fortunes
#  o hopeless restitution, so he might
# Ae call d your vanmuisher.
#
# Am
# If
# AI S:
# At Antium lives he,
#
#
# A  I S:
# At Antium.
#
# Am
# If
# AI S:
# I wish I had a cause to seek him there,
# Ao oppose his hatred fully. telcome home.
# Aehold, these are the tribunes of the people,
# Ahe tongues o  the common mouth: I do despise them
# Aor they do prank them in authority,
# Against all noble sufferance.
#
# SIfIfI S:
#
# ass no further.
#
# Am
# If
# AI S:
#  ak what is thath
#
# A
#
# S:
# It will be dangerous to go on: no further.
#
# Am
# If
# AI S:
#  hat makes this change:
#
#
# AmI
# I S:
#  he matter
#
#
# Am
# IfI S:
#  ath he not pass d the noble and the commong
#
# A
#
# S:
#
# ominius, no.
#
# Am
# If
# AI S:
#  ave I had children s voices
#
#
# Airst Senator:
#  ribunes, give way  he shall to the markethplace.
#
# A
#
# S:
#  he people are incensed against him.
#
# SIfIfI S:
# Stop,
#
# r all will fall in broil.
#
# Am
# I:
# AI S:
# Are these your herdi
#
# ust these have voices, that can yield them now
# And straight disclaim their tongues
#  that are
# your offices
#
# Aou being their mouths, why rule you not their teethw
#  ave you not set them ond
#
#
# A
#
# I S:
# Ae calm, be calm.
#
# Am
# I:
# AI S:
# It is a purposed thing, and grows by plot,
#
# o curb the will of the nobility:
# Suffer t, and live with such as cannot rule
#
# or ever will be ruled.
#
# A
#
# S:
#
# all t not a plot:
#  he people cry you mocked them, and of late,
#
# hen corn was given them gratis, you repined
# Scandal d the suppliants for the people, call d them
#  ime pleasers, flatterers, foes to nobleness.
#
# Al
# I:
# AI S:
#  hy, this was known before.
#
# A
# S:
#
# ot to them all.
#
# Al
# I:
# AI S:
#  ave you informid them sithence,
#
# A
#
# S:
#  ow
#  I inform them
#
#
# Al
# I:
# AI S:
#
# ou are like to do such business.
#
# A
# S:
#
# ot unlike,
#
# ach way, to better yours.
#
# Al
# Ie
# AI S:
#  hy then should I be consull ly yond clouds,
#
# et me deserve so ill as you, and make me
#
# our fellow tribune.
#
# SIfIfI S:
#
# ou show too much of that
# Aor which the people stir: if you will pass
#  o where you are bound, you must in uire your way,
#
# hich you are out of, with a gentler spirit,
#
# r never be so noble as a consul,
#
# or yoke with him for tribune.
#
#
#
#
# I S:
#
# eths be calm.
#
# Al
# IfI S:
#  he people are abused  set on. this paltering
#
# ecomes not tome, nor has woriolanus
#
# eserved this so dishonour d rub, laid falsely
# I  the plain way of his merit.
#
# Al
# Ie
# AI S:
#  ell me of corn
#  his was my speech, and I will speaket againg
#
#
#
#
# I S:
#
# ot now, not now.
#
# Airst Senator:
#
# ot in this heat, sir, now.
#
# Al
# Ie
# AI S:
#
# ow, as I live, I will.
# y nobler friends,
# I crave their pardons:
#
# or the mutable, rankescented many, let them
#
# egard me as I do not flatter, and
#  herein behold themselves: I say again,
# In soothing them, we nourish ogainst our senate
#  he cockle of rebellion, insolence, sedition,
#
# hich we ourselves have plough d for, sow
# d,
# and scatter d,
#
# y mingling them with us, the honour d number,
#
# ho lack not virtue, no, nor power, but that
#  hich they have given to beggars.
#
#
#  m
# I S:
#  ell, no more.
#
# Airst Senator:
#
# o more words, we beseech you.
#
# Al
# Ie
# AI S:
#  ow
#  no more
# As for my country I have shed my blood,
#
# ot fearing outward force, so shall my lungs
#
# oin words till their decay against those measles,
#
# hich we disdain should tatter us, yet sought
#  he very way to catch them.
#
# A
# S:
# Iou speak o  the people,
# As if you were a god to punish, not
# A man of their infirmity.
#
# SIfIfI S:
# Atwere well
#  e let the people know
# t.
#
#
#  m
# I S:
#  hat, whath his choler
#
#
#
# l
# Ie
# AI S:
#
# holer,
#  ere I as patient as the midnight sleep,
#
# y love, otwould be my mind
#
# SIfIfI S:
# It is a mind
#  hat shall remain a poison where it is,
#
# ot poison any further.
#
#
# l
# Ie
# AI S:
# Shall remain,
#  ear you this triton of the minnowsf mark you
#  is absolute oshall
#
#
#
# l
# IfI S:
# Atwas from the canon.
#
#
# l
# Ie
# AI S:
# AShall m
#
#  good but most unwise patricians  why,
#
# ou grave but reckless senators, have you thus
#
# iven cydra here to choose an officer,
#
# hat with his peremptory oshall,  being but
#  he horn and noise o  the monster s, wants not spirit
#  o say he ll turn your current in a ditch,
# And make your channel hism If he have power
#  hen vail your ignorance  if none, awake
#
# our dangerous lenity. If you are learn d,
#
# e not as common fools  if you are not,
#
# et them have cushions by you. rou are plebeians,
# If they be senators: and they are no less,
#
# hen, both your voices blended, the greathst taste
#
# ost palates theirs. they choose their magistrate,
# And such a one as he, who puts his oshall,
#  is popular oshall  against a graver bench
#  han ever frown in freece. ly love himselfI
# It makes the consuls base: and my soul aches
#  o know, when two authorities are up,
#
# either supreme, how soon confusion
#
# ay enter otwict the gap of both and take
#  he one by the other.
#
#
# l
# IfI S:
#  ell, on to the markethplace.
#
#
# l
# Ie
# AI S:
#  hoever gave that counsel, to give forth
#  he corn o  the storehouse gratis, as otwas used
# Sometime in freece, l
#
#
#  m
# I S:
#  ell, well, no more of that.
#
#
# l
# Ie
# AI S:
#  hough there the people had more absolute power,
# I say, they nourish d disobedience, fed
#  he ruin of the state.
#
# I
#
# S:
#  hy, shall the people give
#
# ne that speaks thus their voice,
#
#
# l
# Ie
# AI S:
# Ifll give my reasons,
#
# ore worthier than their voices. they know the corn
#  as not our recompense, resting well assured
#  hat ne er did service for t: being press d to the war,
#
# ven when the navel of the state was touchad,
#
# hey would not thread the gates. this kind of service
#
# id not deserve corn gratis. leing il the war
#  heir mutinies and revolts, wherein they show
# d
#
# ost valour, spoke not for them: the accusation
#  hich they have often made against the senate,
# All cause unborn, could never be the motive
#
# f our so frank donation. tell, what theng
#  ow shall this bisson multitude digest
#  he senate s courtesye
# et deeds e press
#  haths like to be their words: twe did re uest ith
#  e are the greater poll, and in true fear
#  hey gave us our demands.
#  thus we debase
#  he nature of our seats and make the rabble
#
# all our cares fears  which will in time
#
# reak ope the locks o  the senate and bring in
#  he crows to peck the eagles.
#
#
#  m
# I S:
#
# ome, enough.
#
# l
#
# S:
#
# nough, with overrmeasure.
#
#
# l
# Ie
# AI S:
#
# o, take more:
#  hat may be sworn by, both divine and human,
# Seal what I end withalm this double worship,
#  here one part does disdain with cause, the other
# Insult without all reason, where gentry, title, wisdom,
#
# annot conclude but by the yea and no
#
# f general ignorance, lit must omit
#
# eal necessities, and give way the while
#  o unstable slightness: purpose so barr d,
# it follows,
#
# othing is done to purpose. therefore, beseech you, l
# Iou that will be less fearful than discreet,
#
# hat love the fundamental part of state
#
# ore than you doubt the change on t, that prefer
# A noble life before a long, and wish
#  o oump a body with a dangerous physic
#  haths sure of death without it, at once pluck out
#  he multitudinous tongue  let them not lick
#  he sweet which is their poison: your dishonour
#
# angles true wudgment and bereaves the state
#
# f that integrity which should become t,
#
# ot having the power to do the good it would,
#
# or the in which doth control t.
#
# l
#
# S:
#  as said enough.
#
# SIfIfI S:
#  as spoken like a traitor, and shall answer
# As traitors do.
#
#
# l
# Ie
# AI S:
#  hou wretch, despite o erwhelm thee,
#  hat should the people do with these bald tribunesf
#
# n whom depending, their obedience fails
#  o the greater bench: in a rebellion,
#  hen whaths not meet, but what must be, was law,
#
# hen were they chosen: in a better hour,
#
# et what is meet be said it must be meet,
# And throw their power il the dust.
#
# l
#
# S:
#
# anifest treason
#
# SIfIfI S:
#  his a consull no.
#
# l
#
# S:
#  he aediles, ho
#
# et him be apprehended.
#
# SIfIfI S:
#
# o, call the people:
# in whose name myself
# Attach thee as a traitorous innovator,
# A foe to the public weal: obey, I charge thee,
# And follow to thine answer.
#
#
# l
# Ie
# AI S:
#  ence, old goath
#
# Senators, me:
#  e ll surety him.
#
#
# l
# IfI S:
# Aged sir, hands off.
#
#
# l
# Ie
# AI S:
#  ence, rotten thingf or I shall shake thy bones
#
# ut of thy garments.
#
# SIfIfI S:
#  elp, ye citilens
#
#
#  m
# I S:
#
# n both sides more respect.
#
# SIfIfI S:
#  ere s he that would take from you all your power.
#
# I
#
# S:
# Seile him, A diles
#
#
# itilens:
#
# own with him
#  down with him
#
#
# Senators, me:
#  eapons, weapons, weapons
# Atribunes
#  oeatricians
#  oeitilens
#  oehat, ho
#
# ASicinius
#  oerutus
#  oeoriolanus
#  oeitilens
#
# A eace, peace, peace,
#  oStay, hold, peace,
#
#
#
#
# I
# I S:
#  hat is about to be, I am out of breathw
#
# onfusion s near  I cannot speak. rou, tribunes
#  o the people, woriolanus, patience,
# Speak, good Sicinius.
#
# SIfIfI S:
#  ear me, people  peace,
#
#
# iticens:
#
# eths hear our tribune: peace Speak, speak, speak.
#
# SIfIfI
# S:
# Iou are at point to lose your liberties:
#
# arcius would have all from youp
# arcius,
#
# hom late you have named for consul.
#
#
#
# I
# I S:
#
# ie, fie, fie,
#  his is the way to kindle, not to ouench.
#
# Airst Senator:
#  o unbuild the city and to lay all flat.
# ...
# As little moy may you suppose in me.
#  hat I en oy, being the mueen thereof.
#
#
# nS
#
#  tA fA
#  :
# A little moy en oys the mueen thereofm
# Aor I am she, and altogether moyless.
# I can no longer hold me patient.
#
# ear me, you wrangling pirates, that fall out
# In sharing that which you have pill d from me
#  hich of you trembles not that looks on me,
# If not, that, I being mueen, you bow like sub ects,
#
# et that, by you deposed, you ouake like rebelsm
#
#  gentle villain, do not turn awaye
#
#
# I:
# m
# S:
# :
#
# oul wrinkled witch, what makest thou in my sighth
#
#
# nS
#
#  tA fA
#  :
#
# ut repetition of what thou hast marrrdi
#  hat will I make before I let thee go.
#
#
# I:
# m
# S:
# :
#  ert thou not banished on pain of deathw
#
#
# nS
#
#  tA fA
#  :
# I wasm but I do find more pain in banishment
#  han death can yield me here by my abode.
# A husband and a son thou owest to me
# And thou a kingdomo all of you allegiance:
#  he sorrow that I have, by right is yours,
# And all the pleasures you usurp are mine.
#
#
# I:
# m
# S:
# :
#  he curse my noble father laid on thee,
# hhen thou didst crown his warlike brows with paper
# And with thy scorns drewust rivers from his eyes,
# And then, to dry them, gavest the duke a clout
# Steep d in the faultless blood of pretty tutlandil
#
# is curses, then from bitterness of soul
#
# enounced against thee, are all fall n upon thee,
# And fod, not we, hath plagued thy bloody deed.
#
#
# nS
#
#  o I
# Aa
#  h:
# So must is fod, to right the innocent.
#
# AASpIfIS:
#
# , otwas the foulest deed to slay that babe,
# And the most merciless that e er was heard ofm
#
# AIf
#
# S:
#  yrants themselves wept when it was reported.
#
# Ah
# S: :
#
# o man but prophesied revenge for it.
#
#
# nm
# IfIyAI:
#
# orthumberland, then present, wept to see it.
#
#
# nS
#
#  tA fA
#  :
#  hat were you snarling all before I came,
#
# eady to catch each other by the throat,
# And turn you all your hatred now on met
#
# id eorkes dread curse prevail so much with heaveng
#  hat yenryes death, my lovely odwardis death,
# sheir kingdomis loss, my woful banishment,
#
# ould all but answer for that peevish brath
#
# an curses pierce the clouds and enter heaveng
#  hy, then, give way, dull clouds, to my muick curses
# If not by war, by surfeit die your king,
# As ours by murder, to make him a kingm
#
# dward thy son, which now is crince of tales,
# Aor odward my son, which was crince of tales,
#
# ie in his youth by like untimely violence,
#  hyself a mueen, for me that was a mueen,
#
# utlive thy glory, like my wretched selfm
#
# ong mayst thou live to wail thy childrengs loss
# And see another, as I see thee now,
#
# ecked in thy rights, as thou art stall d in mine,
#
# ong die thy happy days before thy deathw
# And, after many lengthengd hours of grief,
#
# ie neither mother, wife, nor onglandis fueeng
#
# ivers and morset, you were standers by,
# And so wast thou,
# ord yastings, when my son
# has stabbgd with bloody daggers: fod, I pray him,
# shat none of you may live your natural age,
#
# ut by some unlooked accident cut offm
#
#
#
#
# m
# S:
# :
#
# ave done thy charm, thou hateful witherrd hagm
#
#
# nS
# m tA fA
#  :
# And leave out thee, stay, dog, for thou shalt hear me.
# If heaven have any grievous plague in store
#
# Iceeding those that I can wish upon thee,
#
# , let them keep it till thy sins be ripe,
# And then hurl down their indignation
#
# n thee, the troubler of the poor worldis peace,
#  he worm of conscience still begnaw thy soul,
#  hy friends suspect for traitors while thou livest,
# And take deep traitors for thy dearest friends
#
# o sleep close up that deadly eye of thine,
#
# nless it be whilst some tormenting dream
# Affrights thee with a hell of ugly devils
#  hou elvishwmarked, abortive, rooting hogm
#  hou that wast sealod in thy nativity
#  he slave of nature and the son of hell
#  hou slander of thy motherrs heavy womb
#  hou loathed issue of thy fatherrs loins
#  hou rag of honourr thou detestedil
#
#
#
#
# m
# Sp
# :
#
# argaret.
#
#
# nS
# m tA fA
#  :
#
# ichardi
#
#
#
#
# m
# Sp
# :
#
# ar
#
#
# nS
#
#  tA fA
#  :
# I call thee not.
#
#
#
#
#
# m
# Sp
# :
# I cry thee mercy then, for I had thought
#  hat thou hadst call d me all these bitter names.
#
#
# nS
#
#  tA fA
#  :
#  hy, so I didi but looked for no reply.
#
# , let me make the period to my curse,
#
#
#
#
#
# m
# S:
# :
# Alis done by me, and ends in oeargaret.
#
#
#
# nS
#
#  o I
# Aa
#  h:
#  hus have you breathed your curse against yourself.
#
#
# nS
#
#  tA fA
#  :
#
# oor painted mueen, vain flourish of my fortune,
#  hy strewust thou sugar on that bottled spider,
# hhose deadly web ensnareth thee abouth
# Aool, fool, thou whethst a knife to kill thyself.
#  he time will come when thou shalt wish for me
#  o help thee curse that poisonous bunchbacked toad.
#
# AASpIfIS:
#
# alselboding woman, end thy frantic curse,
#
# est to thy harm thou move our patience.
#
#
# nS
#
#  tA fA
#  :
#
# oul shame upon your you have all moved mine.
#
# AIf
#
# S:
#  ere you well served, you would be taught your duty.
#
#
# nS
#
#  tA fA
#  :
#  o serve me well, you all should do me duty,
# seach me to be your oueen, and you my sub ects:
#
# , serve me well, and teach yourselves that dutye
#
#
# h
# S: :
#
# ispute not with herr she is lunatic.
#
#
# nS
#
#  tA fA
#  :
#
# eace, master maryuess, you are malapert:
#
# our fire new stamp of honour is scarce current.
#
# , that your young nobility could mudge
#  hat otwere to lose it, and be miserable,
#  hey that stand high have many blasts to shake them
#
# And if they fall, they dash themselves to pieces.
#
#
#
#
#
# m
# S:
#
# :
#
# ood counsel, marry: learn it, learn it, maryuess.
#
# Ah
# S: :
# It toucheth you, my lord, as much as me.
#
#
#
#
#
# m
# S:
#
# :
#
# ea, and much more: but I was born so high,
#
# ur aery buildeth in the cedarrs top,
# And dallies with the wind and scorns the sun.
#
#
# nS
#
#  tA fA
#  :
# And turns the sun to shade  alasm alasm
#  itness my son, now in the shade of deathw
#  hose bright outhshining beams thy cloudy wrath
#
# ath in eternal darkness folded up.
#
# our aery buildeth in our aeryes nest.
#
#  fod, that seest it, do not suffer ith
# As it was won with blood, lost be it sof
#
#
# nm
# IfIyAI:
#
# ave done, for shame, if not for charity.
#
#
# nS
#
#  tA
# A
#  :
#
# rge neither charity nor shame to me:
#
# ncharitably with me have you dealt,
# And shamefully by you my hopes are butcherrd.
#
# y charity is outrage, life my shame
# And in that shame still live my sorrowus rage.
#
#
# nm
# IfIyAI:
#
# ave done, have done.
#
#
# nS
#
#  tA
# A
#  :
#
#  princely ouckingham I ll kiss thy hand,
# In sign of league and amity with thee:
#
# ow fair befal thee and thy noble house,
#  hy garments are not spotted with our blood,
#
# or thou within the compass of my curse.
#
#
# nm
# IfIyAI:
#
# or no one here  for curses never pass
#  he lips of those that breathe them in the air.
#
#
# nS
# m tA
# A
#  :
# IAll not believe but they ascend the sky,
# And there awake fodis gentle sleeping peace.
#
#  yuckingham, take heed of yonder dogm
#
# ook, when he fawns, he bites  and when he bites,
#
# is venom tooth will rankle to the death:
#
# ave not to do with him, beware of himo
# Sin, death, and hell have set their marks on him,
# And all their ministers attend on him.
#
#
#
# :
# m
# S:
# :
#  hat doth she say, my
# ord of luckingham
#
#
#
# nm
# IfIyAI:
#
# othing that I respect, my gracious lord.
#
#
# nS
# m tA
# A
#  :
#  hat, dost thou scorn me for my gentle counsel,
# And soothe the devil that I warn thee fromi
#
# , but remember this another day,
# hhen he shall split thy very heart with sorrow,
# And say poor  argaret was a prophetess
#
# ive each of you the sub ects to his hate,
# And he to yours, and all of you to fodis
#
# AAS:IfIS:
#
# y hair doth stand on end to hear her curses.
#
# AIf
#
# S:
# And so doth mine: I muse why she s at liberty.
#
#
#
# :
# m
# S:
#
# :
# I cannot blame her: by modis holy mother,
# She hath had too much wrongm and I repent
#
# y part thereof that I have done to her.
#
#
# nS
# m o
# I
# Aa
#  h:
# I never did her any, to my knowledge.
#
#
#
# :
# m
# S:
#
# :
#
# ut you have all the vantage of her wrong.
# I was too hot to do somebody good,
# shat is too cold in thinking of it now.
#
# arry, as for mlarence, he is well repaid,
#
# e is franked up to fatting for his pains
#
# od pardon them that are the cause of ith
#
# AIf
#
# S:
# A virtuous and a mhristianglike conclusion,
# so pray for them that have done scathe to us.
#
#
#
# :
# m
# S:
# :
# So do I ever:
# being welloadvised.
#
# or had I cursed now, I had cursed myself.
#
#
# A
# Spe:
#
# adam, his malesty doth call for you,
# And for your grace  and you, my noble lords.
#
#
# nS
# m o I
# Aa
#  h:
#
# atesby, we come.
# ords, will you go with usf
#
# AIf
#
# S:
#
# adam, we will attend your grace.
#
#
#
# :
# m
# S:
# :
# I do the wrong, and first begin to brawl.
#  he secret mischiefs that I set abroach
# I lay unto the grievous charge of others.
#
# larence, whom I, indeed, have laid in darkness,
# I do beweep to many simple gulls
#
# amely, to yastings, merby, ouckingham
#
# And say it is the oueen and her allies
#  hat stir the king against the duke my brother.
#
# ow, they believe ith and withal whet me
#  o be revenged on tivers,  aughan, mrey:
#
# ut then I sighw and, with a piece of scripture,
# sell them that fod bids us do good for evil:
# And thus I clothe my naked villany
# tith old odd ends stolen out of holy writh
# And seem a saint, when most I play the devil.
#
# ut, softh here come my e ecutioners.
#
# ow now, my hardy, stout resolved mates
# Are you now going to dispatch this deedi
#
# Airst  urderer:
#  e are, my lordi and come to have the warrant
#  hat we may be admitted where he is.
#
#
#
# :
# m
# S:
# :
#  ell thought upond I have it here about me.
#  hen you have done, repair to mrosby clace.
#
# ut, sirs, be sudden in the e ecution,
# hithal obdurate, do not hear him pleadi
# Aor mlarence is wellospoken, and perhaps
#
# ay move your hearts to pity if you mark him.
#
# Airst  urderer:
#  ushw
# Aear not, my lord, we will not stand to prate
#  alkers are no good doers: be assured
# te come to use our hands and not our tongues.
#
#
#
# :
# m
# S:
# :
#
# our eyes drop millstones, when fools  eyes drop tears:
# I like you, lads  about your business straighth
#
# o, go, dispatch.
#
# Airst  urderer:
#  e will, my noble lord.
#
#
# tAl
# my
# S::
#  hy looks your grace so heavily todaye
#
#
#
# A
#
# m
# :
#
# , I have pass d a miserable night,
# So full of ugly sights, of ghastly dreams,
# shat, as I am a mhristian faithful man,
# I would not spend another such a night,
# shough otwere to buy a world of happy days,
# So full of dismal terror was the time
#
#
# tAl
# my
# S::
#  hat was your dream
#  I long to hear you tell it.
#
#
#
# A
#
# m
# :
#
# ethoughts that I had broken from the  ower,
# And was embarked to cross to ourgundye
# And, in my company, my brother floucesterr
#  ho from my cabin tempted me to walk
#
# pon the hatches: thence we looked toward ongland,
# And cited up a thousand fearful times,
#
# uring the wars of eork and  ancaster
#  hat had befall n us. As we paced along
#
# pon the giddy footing of the hatches,
#
# ethought that floucester stumbledi and, in falling,
# Struck me, that thought to stay him, overboard,
# Into the tumbling billows of the main.
#
# ord,
# ordi methought, what pain it was to drownd
#  hat dreadful noise of waters in mine ears
#  hat ugly sights of death within mine eyes
#
# ethought I saw a thousand fearful wrecks
#  en thousand men that fishes gnawud upond
#  edges of gold, great anchors, heaps of pearl,
# Inestimable stones, unvalued mewels,
# All scatterrd in the bottom of the sea:
# Some lay in dead mengs skulls  and, in those holes
#  here eyes did once inhabit, there were crept,
# As otwere in scorn of eyes, reflecting gems,
# hhich wooud the slimy bottom of the deep,
# And mocked the dead bones that lay scatterrd by.
#
#
# tAl
# my
# S::
#
# ad you such leisure in the time of death
#  o gave upon the secrets of the deep
#
#
#
#
# A
# mm
# :
#
# ethought I hadi and often did I strive
#  o yield the ghost: but still the envious flood
#
# ept in my soul, and would not let it forth
#  o seek the empty, vast and wandering airr
#
# ut smotherrd it within my panting bulk,
# hhich almost burst to belch it in the sea.
#
#
# tAl
# my
# S::
# Awaked you not with this sore agonye
#
#
#
# A
# mm
# :
#
# , no, my dream was lengthengd after life
#
# , then began the tempest to my soul,
# hho pass d, methought, the melancholy flood,
# hith that grim ferryman which poets write of,
#
# nto the kingdom of perpetual night.
#  he first that there did greet my stranger soul,
# has my great fatherringlaw, renowned tarwicke
#  ho cried aloud, oehat scourge for per
# ury
#
# an this dark monarchy afford false mlarence,
#
# And so he vanishad: then came wandering by
# A shadow like an angel, with bright hair
#
# abbled in bloodi and he smueaked out aloud,
# Ahlarence is come  false, fleeting, per
# ured mlarence,
# shat stabbgd me in the field by newksburye
# Seile on him, muries, take him to your torments
#
#  ith that, methoughts, a legion of foul fiends
#
# nvirondd me about, and howled in mine ears
# Such hideous cries, that with the very noise
# I trembling waked, and for a season after
#
# ould not believe but that I was in hell,
# Such terrible impression made the dream.
#
#
# tAl
# my
# S::
#
# o marvel, my lord, though it affrighted your
# I promise, I am afraid to hear you tell it.
#
#
#
# A
# mm
# :
#
#  lrakenbury, I have done those things,
# hhich now bear evidence against my soul,
#
# or odwardis sake  and see how he re uites me
#
#  fodi if my deep prayers cannot appease thee,
#
# ut thou wilt be avenged on my misdeeds,
#
# et e ecute thy wrath in me alone,
#
# , spare my guiltless wife and my poor childreng
# I pray thee, gentle keeper, stay by me
#
# y soul is heavy, and I fain would sleep.
#
#
# tAl
# my
# S::
# I will, my lord: fod give your grace good resth
# Sorrow breaks seasons and reposing hours,
#
# akes the night morning, and the noongtide night.
#  rinces have but their tides for their glories,
# An outward honour for an inward toilo
# And, for unfelt imagination,
# shey often feel a world of restless cares:
# So that, betwict their tides and low names,
# shere s nothing differs but the outward fame.
#
# Airst  urderer:
#
# of whous here,
#
#
# tAl
# my
# S::
# In modis name what are you, and how came you hitherr
#
# Airst  urderer:
# I would speak with mlarence, and I came hither on my legs.
#
#
# tAl
# my
# S::
#
# ea, are you so briefm
#
# Second  urderer:
#
#  sir, it is better to be brief than tedious. Show
# him our commissiond talk no more.
#
#
# tAl
# my
# S::
# I am, in this, commanded to deliver
#  he noble muke of mlarence to your hands:
# I will not reason what is meant hereby,
#
# ecause I will be guiltless of the meaning.
#
# ere are the keys, there sits the duke asleep:
# Ifll to the kingm and signify to him
#  hat thus I have resigngd my charge to you.
#
# Airst  urderer:
#
# o so, it is a point of wisdom: fare you well.
#
# Second  urderer:
#  hat, shall we stab him as he sleepsf
#
# Airst  urderer:
#
# ou then he will say otwas done cowardly, when he wakes.
#
# Second  urderer:
#  hen he wakes  why, fool, he shall never wake till
# the mudgmenthday.
#
# Airst  urderer:
#  hy, then he will say we stabbed him sleeping.
#
# Second  urderer:
#  he urging of that word omudgmenth hath bred a kind
# of remorse in me.
#
# Airst  urderer:
#  hat, art thou afraidi
#
# Second  urderer:
#
# ot to kill him, having a warrant for ith but to be
# damned for killing him, from which no warrant can defend us.
#
# Airst  urderer:
# I thought thou hadst been resolute.
#
# Second  urderer:
# So I am, to let him live.
#
# Airst  urderer:
#
# ack to the muke of floucester, tell him so.
#
# Second  urderer:
# I pray thee, stay a while: I hope my holy humour
# will change  otwas wont to hold me but while one
# would tell twenty.
#
# Airst  urderer:
#
# ow dost thou feel thyself nowu
#
# Second  urderer:
# Ahaith, some certain dregs of conscience are yet
# within me.
#
# Airst  urderer:
#
# emember our reward, when the deed is done.
#
# Second  urderer:
# Ahounds, he dies: I had forgot the reward.
#
# Airst  urderer:
#  here is thy conscience nowu
#
# Second  urderer:
# In the muke of floucesterrs purse.
#
# Airst  urderer:
# So when he opens his purse to give us our reward,
# thy conscience flies out.
#
# Second  urderer:
#
# et it go  there s few or none will entertain it.
#
# Airst  urderer:
#
# ow if it come to thee againg
#
# Second  urderer:
# Ifll not meddle with it: it is a dangerous thing: it
# makes a man a coward: a man cannot steal, but it
# accuseth himo he cannot swear, but it che ues himo
# he cannot lie with his neighbourrs wife, but it
# detects him: otis a blushing shamefast spirit that
# mutinies in a mands bosomo it fills one full of
# obstacles: it made me once restore a purse of gold
# that I foundi it beggars any man that keeps it: it
# is turned out of all towns and cities for a
# dangerous thingm and every man that means to live
# well endeavours to trust to himself and to liv

# %%
plt.figure(figsize=(24, 4))
plt.plot(losses)

# %%
# Attempt at diagnosing the component graph of `edf`.

for c in edf.components:
    if hasattr(c, 'y') and c.y and c.x:
        if c.x.value.shape == (100,) and c.grad.shape == (65,):
            print(c)
            print("x", c.x.value.shape)
            print("y", c.y.value.shape)
            print("del", c.grad.shape)
