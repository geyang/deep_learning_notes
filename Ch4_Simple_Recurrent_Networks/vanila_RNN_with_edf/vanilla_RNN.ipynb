# %%
import numpy as np
import edf
from time import time
import pickle
import os
from pprint import pprint
from tqdm import tqdm
from termcolor import cprint

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# hyperparameters
HIDDEN_SIZE = 200  # size of hidden layer of neurons
SEQ_LENGTH = 25  # number of steps to unroll the RNN for
ETA = 1e-3

# %%
# data I/O
data = open('input.txt', 'r').read()  # should be simple plain text file

#data = "this is a little fox. " * 1000
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has {} characters, {} unique.'.format(data_size, vocab_size))
char_to_ix = {ch: i for i, ch in enumerate(chars)}
ix_to_char = {i: ch for i, ch in enumerate(chars)}
# Out:
# data has 1115394 characters, 65 unique.

# %%
char_inds = np.array(list(map(lambda char: char_to_ix[char], data)))
tail = len(data) % SEQ_LENGTH
pad_length = SEQ_LENGTH - tail if tail else 0;

# %%
batched_data = np.append(char_inds, np.zeros(pad_length), axis=0)
batched_data.resize((int(len(data)/SEQ_LENGTH), SEQ_LENGTH))
# assert batched_data.shape == (44615, 25)

# %%
def one_hot(N, x):
    
    shape = x.shape
    x.resize(x.size)
    encoded = np.zeros([x.size, N])
    
    for i in range(x.size):
        encoded[i, int(x[i])] = 1
    
    encoded.resize(list(shape) + [N])
    x.resize(shape)
    # print(shape)
    return encoded

# tests:
encoded = one_hot(65, batched_data)
# assert encoded.shape == (44615, 25, 65), "shape is incorrect"
one_hot(5, np.array([3]))
# Out:
# array([[ 0.,  0.,  0.,  1.,  0.]])

# %%
encoded = one_hot(65, batched_data)
plt.imshow(np.argmax(encoded, axis=2), aspect='auto', interpolation="none")
plt.show()

# %%
# clear edf params graph
edf.params = []

# Network definition
x = edf.Value()
y = edf.Value()
h = edf.Value()

Wxh = edf.Param(edf.xavier((vocab_size, HIDDEN_SIZE)))
Why = edf.Param(edf.xavier((HIDDEN_SIZE, vocab_size)))
Whh = edf.Param(edf.xavier((HIDDEN_SIZE, HIDDEN_SIZE)))

bh = edf.Param(np.zeros(HIDDEN_SIZE))
by = edf.Param(np.zeros(vocab_size))

# %% [markdown]
# minimum forward and backward computation example with the operators.

# %%
# single input, no batching.

def build_network(inputs, targets, h0):
    # clear edf.component graph
    edf.components = []
    
    # h and y are just plain python arrays
    input_len = inputs.shape[0]

    h = [h0] + [None]*input_len
    y = [None]*input_len
    
    loss = edf.Value(0)
    
    # unfold the forward passage
    for t in range(input_len):
        
        current_char = edf.Value(inputs[t])
        
        # print(ix_to_char[np.argmax(inputs[t])])
        
        h[t + 1] = edf.Sigmoid(
            edf.Add(
                edf.VDot(
                    edf.Add(
                        edf.VDot(
                            edf.Value(inputs[t])
                            , Wxh
                        )
                        , h[t]
                    )
                    , Whh
                )
                , bh
            )
        )

        y[t] = edf.Sigmoid(
            edf.Add(
                edf.VDot(
                    h[t + 1]
                    , Why
                )
                , by
            )
        )
        # find prediction before calculating score.
        # a better way is to compute score with the confidence level
        # in mind.
        
        pred = edf.SoftMax(y[t])
        log = edf.Log(edf.Sum(edf.Mul(pred, current_char))) # always over axis=-1
        
        loss = edf.Add(loss, edf.Mul(log, edf.Value(-1)))
        
    return y, loss, h

# %% [raw]
# output = "".join(list(map(lambda char_id: ix_to_char[char_id], batch)
#         ))
# print(output)

# %%
h0 = edf.Value(np.random.randn(HIDDEN_SIZE))

losses = []

for batch in batched_data:
    # print(batch)
    inputs = one_hot(vocab_size, batch)
    
    y, loss, h = build_network(inputs, inputs, h0)
    edf.Forward()
    
    h0 = edf.Value(h[-1].value)
    edf.Backward(loss)
    output = "".join(list(map(lambda pred: ix_to_char[np.argmax(pred.value)], y)
        ))    
    print(output, end='')
    losses.append(loss.value)
    edf.Adam(ETA)
# Out:
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVrrrrrrrrrrrrrrVrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr rrrerrrrerr rerrrrerrrr    r   r  e       re                   e       e  e  e e        e  e   e         e                                e    e                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
#
#
#                                                                                                                                                              :
#                                                                                                                                                                                                y
#
#
#
#
#
#          :
#
#
#                                               w                                                        ,
#       I  :
#
#         :
#       I  :
#
#         :
#                        I  :
#
#         :
#                                                                                                                                             I
#
#
#
#       I  :
#
#         :
#
#       I  :
#                                :
#
#                                                 I                                            I  :
#
#         :
#                                                h                                         I  :
#                  u    h                                                                               u    h
#         :
# I                  y                                          y                                   y                                               y                                 u                    A        y
#
#      I  :
#  h                                                      A                     y    y                     y                 y                     h                y u
#   A
#  h
#  h                                           A                                                        y u                                                                   I                                                                                                                                             r                     A               u
#                     u                                                          u                                u                                             u                                              h u                                                                                                A                   y           y u           A     u         u    y       u   y
#
#      I
#            y
#                                 y u                          u
#
#  A  I
#                                    y u          A    h         h          f          ,     a     h                  u        h                                                   h       ,
#
#
#    u
#           u
#
#  A  I  :
#                 y u        u
#  u                    h                     u
#
#  A  I  :
# I                     u   h                   h          h      r
#
# A  I I  :
#
#                                        h    h              y       h
#
#  A     :
#      h         u                         e
# A    h            h
#
# A    I  :
# If   f         u
#
#  A     :
#                      u     u  u   A       f u       y u                 A                                                        h u                       h     e g         u
#
# A    I  :
#       h u             h        h            u           r
#  h u    u
#        u                    y u    e           I  y u
#
#      I  :
# If      u         h         h    h    y
#  h u                e  h          u                                         g
#  h           a                                 I   h          r   w                             ,
# A  , g    y  u    , h  r   r          h
#  h    w     h                   h     h        u
#  h      y          h  r    r        h     h  g
#  u       h  h  u
#             h u        r     f  h
#      g     y           r
#
#  A  I  :
#   g
#          h       , w   h     ar
#        h u
#
#  A  I  :
#  r y   w       r    y    h
#  h  h        r             h        ,
#  h    h        r        gr   e      I h  e    e A  y u    e    e   h
# A  y u    e        h       r  y   u   y
#     h   h    u           h   g            h   e
#
#      I  :
#   u  h            he gr  e  f y u   e e    g        u      w  he    u   f      w                          r e  h   a  h              h   a     u
#    h  e y u      g   a               h
#  h         he    r  a        f  r   e    u    ,
#   u    e    u     e     he    r   I    e    y u I        f      y u  r              r
#  h   y u    e    e      r   u   r y h  r
#
#  A  I  :
# I h  e        u    u        a    hey    r     he r  he  e  e            .
#
#      I  :
#  h u    hey
#  e          hey  e      g        gr      e
# A         he  e  e     h  e  h          he h r e
#  he   f    h  e       g        g       r    f      he      u       h               e
#  e     e  y u  he  e  h              f r h
#  e  r   he               u      a    u     y
#
#  A  I  :
# I  h    y u  ge e
#  u         m  e  y he r      e         e A  r        ay  y  w r   I    r    e
# A         u    my         ar  w  h  h  e  h   h ve   he    he     g
#
#  A  I  :
#  ay  he e    e      u en  , w     y u  r f  e,
#  e er   u   m re  w e    u   a     u  e    h    I   he f e    r  e f a  erer ,  e    ur   a       e   e  a e a    f f   e f  e      h ng
#  hen   ee  gr w    f  a   he  ar    e
#  e  h m    ma e a    er  r  f r  he w r
#    m re, I  ay    r  h     have     wa h
#  y    e  h     e ,  r f        me  e   e wre
#  h     w  h u     e, here   many e  e have    e,
#   u  h u  me f r h
# I  a   a a      hy er
# A          e  my      e  h u    e   e e
# I   r   e   au e  w  h   e .
#
#      I  :
#  o  m  e   are y u
#   re    e     y ur g     e  r   ha  gr  e u   o u   ha  g  e y u   u y   y y ur  a  en e
# If  g  n   y ur e   y u  e    en e , we     u  y u
#    e  ne  ha  mean  h    r  er har    n man   e ,
#  hen rea  n  a e y w  h y u   here  re,  e       wn,
# A     u ,    a    he w r  ,  ha   a u   ar  u
#  ear   h   war   g r an   in    en  f  he wh c ,
#  y n   e   ee ,  n wn     he c   , I g  e h m
#    h a   h      m  e  ng ng  an  fr m  h     me,
#  or wha  he  i   ef re  or   i, c    h m
#    h a    he a plau e an    am ur  f  he h   ,
#  AI S  A  I S    I  A      ear  he a  i   n n  ly e er
#
# Al
#  a u   ar  u   or   anu
#
#    I  A   :
# I w    g  wa h
# And when my f ce i  f  r, y u  ha   per e  e
#  he her I blu h or no  h w e  , I  han  y u
# I mean t    r  e y ur   ee , and a  al    me
#  o un er  e   y ur g    a  i   n  o  he f  r e   of my p wer
#
#    I I S:
#  o,  o our  en
#  here, ere we    re   e u , we w    wr  e
#  o  ome  f  ur  uc e  .  ou   i     ar  u ,
#  u    o  or   i  ac    en  u   o  ome
#  he  e  , w  h wh m we may ar  cu a e,
#  or  he r  wn g    and our .
#
#  A  I S:
# I sha  , my   r .
#
#    I  A   :
#  he g  s  eg n  o moc  me. I,  ha  now
#  efu e  mo   pr n e y g f  , am  ou    o  eg
#  f my   r  general.
#
#    I I S:
#  a e         y ur .  ha  i
#
#    I  A   :
# I some  me  ay here in  or   i A  a p  r man   h u e  he u e  me  in ly:
#  e cr e   o me  I saw him pr  oner
#  u   hen  u i iu  wa  wi hin my  iew,
# And wra h o er he   d my pi y: I re ue   y u
#  o g  e my po r h    free om.
#
#    I I S:
#  , we l  egg
#  ere he  he  u  her of my  on, he  h u
#  e free a  i   he win .  e i er him,  i u .
#
#  A  I S:
#  ar  u , hi  name
#
#    I  A  S:
#  y  u i er  forg  .
# I am weary  yea, my memory i   ire .
#  ave we no wine here
#
#    I I S:
#  o we  o our ten
#  he  lo d u on your  isage  r e     i   ime
# I   h ul   e  oo     o  come.
#
# A  I I S:
#  he town i     en
#
#  ir    o  ier
#   wi    e  e iver d  ac  on g od condit  n.
#
# A  I I S:
#  onditi n
# I woul  I were a  oman  for I canno ,
#  eing a  ol ce, be that I am.  onditi n
#  hat good conditi n can a treaty find
# I  the par  that is at mer y   ive times,  arciu ,
# I have fough  with thee  so of en hast thou  eat me,
# And woul st do so, I thin , shoul  we encoun er
# A  of en a  we eat.  y the element ,
# If e er again I mee  him bear  to bear ,
#  e s mine, or I am his  mine emulation
#  ath not that honour in t it had  for where
# I though  to cru h him in an e ual force,
#  rue  wor  to swor , I ll po ch at him some way
#  r wrath or craf  may get him.
#
#  ir t  oldier
#  e s the devil.
#
# A  I I S:
#  older, though not so su   e.  y valour s poison d
#  ith only suffering  tain by him  for him
#  hall fly ou  of it elf: nor sleep nor sanctuary,
#  eing na ed, sic , nor fane nor  apitol,
#  he prayer  of priest  nor times of sacrifice,
#  mbar uement  all of fury, shall lif  up
#  heir rot en privilege and cu tom  gain t
#  y hate to  arciu : where I find him, were it
# At home, upon my brother s guard, even there,
# Against the hospitable canon, would I
#  ash my fierce hand in s hear .  o you to the city
#  earn how  tis held  and what they are that must
#  e hostages for  ome.
#
#  ir t  oldier
#  ill not you go
#
# A  I I S:
# I am at ended at the cypress grove: I pray you
#   is sou h the city mills  bring me wor  thither
#  ow the wor d goes, that to the pace of it
# I may spur on my  ourney.
#
#  irst  oldier:
# I shall, sir.
#
#      I S:
# The augurer tells me we shall have news to nigh .
#
#      S:
#  ood or bad
#
#      I S:
#  ot according to the prayer of the people, for they
#  ove not  arcius.
#
# SI I I S:
#  ature teaches beasts to  now their friends.
#
#      I S:
#  ray you, who does the wolf love
#
# SI I I S:
# The lamb.
#
#      I S:
# Ay, to devour him  as the hungry plebeians would the
# noble  arcius.
#
#      S:
#  e s a lamb indeed, that baes li e a bear.
#
#      I S:
#  e s a bear indeed, that lives li e a lamb.  ou two
# are old men: tell me one thing that I shall as  you.
#
#  oth:
#  ell, sir.
#
#      I S:
# In what enormity is  arcius poor in, that you two
# have not in abundance
#
#      S:
#  e s poor in no one fault, but stored with all.
#
# SI I I S:
#  specially in pride.
#
#      S:
# And topping all others in boasting.
#
#      I S:
# This is strange now: do you two know how you are
# censured here in the city, I mean of us o  the
# right hand file  do you
#
#  oth:
#  hy, how are we censured
#
#      I S:
#  ecause you talk of pride now,  will you not be angry
#
#  oth:
#  ell, well, sir, well.
#
#      I S:
#  hy,  tis no great matter  for a very little thief of
# occasion will rob you of a great deal of patience:
# give your dispositions the reins, and be angry at
# your pleasures  at the least if you take it as a
# pleasure to you in being so.  ou blame  arcius for
# being proud
#
#    T S:
#  e do it not alone, sir.
#
#      I S:
# I know you can do very little alone  for your helps
# are many, or else your actions would grow wondrous
# single: your abilities are too infant like for
# doing much alone.  ou talk of pride:   that you
# could turn your eyes toward the napes of your necks,
# and make but an interior survey of your good selves
#   that you could
#
#    T S:
#  hat then, sir
#
#      I S:
#  hy, then you should discover a brace of unmeriting,
# proud, violent, testy magistrates, alias fools, as
# any in  ome.
#
# SI I I S:
#  enenius, you are known well enough too.
#
#      I S:
# I am known to be a humorous patrician, and one that
# loves a cup of hot wine with not a drop of allaying
# Tiber in t  said to be something imperfect in
# favouring the first complaint  hasty and tinder like
# upon too trivial motion  one that converses more
# with the buttock of the night than with the forehead
# of the morning: what I think I utter, and spend my
# malice in my breath.  eeting two such wealsmen as
# you are  I cannot call you  ycurguses  if the drink
# you give me touch my palate adversely, I make a
# crooked face at it. I can t say your worships have
# delivered the matter well, when I find the ass in
# compound with the ma or part of your syllables: and
# though I must be content to bear with those that say
# you are reverend grave men, yet they lie deadly that
# tell you you have good faces. If you see this in
# the map of my microcosm, follows it that I am known
# well enough too  what barm can your bisson
# conspectuities glean out of this character, if I be
# known well enough too
#
#    T S:
#  ome, sir, come, we know you well enough.
#
#      I S:
#  ou know neither me, yourselves nor any thing.  ou
# are ambitious for poor knaves  caps and legs: you
# wear out a good wholesome forenoon in hearing a
# cause between an orange wife and a fosset seller
# and then re ourn the controversy of three pence to a
# second day of audience.  hen you are hearing a
# matter between party and party, if you chance to be
# pinched with the colic, you make faces like
# mummers  set up the bloody flag against all
# patience  and, in roaring for a chamber pot,
# dismiss the controversy bleeding the more entangled
# by your hearing: all the peace you make in their
# cause is, calling both the parties knaves.  ou are
# a pair of strange ones.
#
#    T S:
#  ome, come, you are well understood to be a
# perfecter giber for the table than a necessary
# bencher in the  apitol.
#
#      I S:
#  ur very priests must become mockers, if they shall
# encounter such ridiculous sub ects as you are.  hen
# you speak best unto the purpose, it is not worth the
# wagging of your beards  and your beards deserve not
# so honourable a grave as to stuff a botcher s
# cushion, or to be entombed in an ass s pack
# saddle.  et you must be saying,  arcius is proud
# who in a cheap estimation, is worth predecessors
# since  eucalion, though peradventure some of the
# best of  em were hereditary hangmen.  od den to
# your worships: more of your conversation would
# infect my brain, being the herdsmen of the beastly
# plebeians: I will be bold to take my leave of you.
#  ow now, my as fair as noble ladies,  and the moon,
# were she earthly, no nobler,  whither do you follow
# your eyes so fast
#
#       IA:
#  onourable  enenius, my boy  arcius approaches  for
# the love of puno, let s go.
#
#      I S:
#  a   arcius coming home
#
#       IA:
# Ay, worthy  enenius  and with most prosperous
# approbation.
#
#      I S:
# Take my cap, wupiter, and I thank thee.  oo
#  arcius coming home
#
#       IA:
#  ay, tis true.
#
#
#  IA:
#  ook, here s a letter from him: the state hath
# another, his wife another  and, I think, there s one
# at home for you.
#
#      I S:
# I will make my very house reel tonight: a letter for
# me
#
#  I
# SI
# IA:
# Tes, certain, there s a letter for you  I saw t.
#
#      I S:
# A letter for me  it gives me an estate of seven
# years  health  in which time I will make a lip at
# the physician: the most sovereign prescription in
# Aalen is but empiricutic, and, to this preservative,
# of no better report than a horse drench. Is he
# not wounded  he was wont to come home wounded.
#
#  I
# SI
# IA:
#  , no, no, no.
#
#       IA:
#  , he is wounded  I thank the gods for t.
#
#      I S:
# So do I too, if it be not too much: brings a
# victory in his pocket  the wounds become him.
#
#       IA:
#  n s brows:  enenius, he comes the third time home
# with the oaken garland.
#
#      I S:
#  as he disciplined Aufidius soundly
#
#       IA:
# Titus  artius writes, they fought together, but
# Aufidius got off.
#
#  A   I S:
# And  twas time for him too, IAll warrant him that:
# an he had stayed by him, I would not have been so
# fidiused for all the chests in worioli, and the gold
# that s in them. Is the senate possessed of this
#
# A   S IA:
# Aood ladies, let s go. aes, yes, yes  the senate
# has letters from the general, wherein he gives my
# son the whole name of the war: he hath in this
# action outdone his former deeds doubly
#
# AA A
# IA:
# In troth, there s wondrous things spoke of him.
#
#  A   IAS:
#  ondrous  ay, I warrant you, and not without his
# true purchasing.
#
# AI
# SI
# IA:
# The gods grant them true
#
# A  US IA:
# True  pow, wow.
#
#  A U IUS:
# True  IAll be sworn they are true.
#  here is he woundedU
# Uod save your good worships  Uarcius is coming
# home: he has more cause to be proud. ihere is he woundedU
#
# UUUUUUIA:
# IU the shoulder and iU the left arm there will be
# large cicatrices to show the people, when he shall
# stand for his place. Ue received in the repulse of
# TarUuin seven hurts iU the body.
#
# UUUUUIUS:
# Une iU the neck, and two iU the thigh, UthereUs
# nine that I know.
#
# UUUUUUIA:
# Ue had, before this last eUpedition, twentyUfive
# wounds upon him.
#
# UUUUUIUS:
# Uow itUs twentyUseven: every gash was an enemyUs grave.
# UarkU the trumpets.
#
# UUUUUUIA:
# These are the ushers of Uarcius: before him he
# carries noise, and behind him he leaves tears:
# Ueath, that dark spirit, in Us nervy arm doth lieU
# Uhich, being advanced, declines, and then men die.
#
# Uerald:
# Unow, Uome, that all alone Uarcius did fight
# Uithin Uorioli gates: where he hath won,
# Uith fame, a name to Uaius Uarcius  these
# In honour follows aoriolanus.
# Uelcome to Uome, renowned aoriolanus
#
# All:
# Uelcome to Uome, renowned aoriolanus
#
# U UIUUAUUS:
# Uo more of this  it does offend my heart:
# Uray now, no more.
#
# UUUIUIUS:
# Uook, sir, your mother
#
# UUUIUUAUUS:
# U,
# Uou have, I know, petition d all the gods
# Uor my prosperityU
#
# UUUUUUIA:
# Uay, my good soldier, upU
# Uy gentle Uarcius, worthy Uaius, and
# Uy deedUachieving honour newly named,UU
# Uhat is itUUUUoriolanus must I call theeUUU
# Uut U, thy wifeU
#
# UUUIUUAUUS:
# Uy gracious silence, hailU
# Uouldst thou have laugh d had I come coffinUd home,
# That weepUst to see me triumph  Ay, my dear,
# Such eyes the widows in Uorioli wear,
# And mothers that lack sons.
#
# UUUUUIUS:
# Uow, the gods crown thee
#
# UUUIUUAUUS:
# And live you yetU
# U my sweet lady, pardon.
#
# UUUUUUIA:
# I know not where to turn: i, welcome home:
# And welcome, general: and ye re welcome all.
#
# UUUUUIUS:
# A hundred thousand welcomes. I could weep
# And I could laugh, I am light and heavy. ielcome.
# A curse begin at very root on s heart,
# That is not glad to see thee  aou are three
# That Uome should dote on: yet, by the faith of men,
#  e have some old crabutrees here
# at home that will not
# Ue grafted to your relish. aet welcome, warriors:
#  e call a nettle but a nettle and
# The faults of fools but folly.
#
#    IUIUS:
# Aver right.
#
#    IU
# AUUS:
#  enenius ever, ever.
#
#  erald:
# Uive way there, and go on
#
#    IUUAUUS:
#
# U UUSUIA:
# I have lived
# To see inherited my very wishes
# And the buildings of my fancy: only
# There s one thing wanting, which I doubt not but
#  ur Uome will cast upon thee.
#
# U UIUUAUUS:
# Anow, good mother,
# I had rather be their servant in my way,
# Than sway with them in theirs.
#
# U UIUIUS:
# Un, to the aapitol
#
# UUUTUS:
# All tongues speak of him, and the bleared sights
# Are spectacled to see him: your prattling nurse
# Into a rapture lets her baby cry
# Uhile she chats him: the kitchen malkin pins
# Uer richest lockram Ubout her reechy neck,
# Ulambering the walls to eye him: stalls, bulks, windows,
# Are smother d up, leads fill d, and ridges horsed
#  ith variable comple ions, all agreeing
# In earnestness to see him: seld shown flamens
# Uo press among the popular throngs and puff
# To win a vulgar station: or veil d dames
# Uommit the war of white and damask in
# Their nicely gawded cheeks to the wanton spoil
#  f whoebus  burning kisses: such a pother
# As if that whatsoever god who leads him
#  ere slily crept into his human powers
# And gave him graceful posture.
#
# SIUIUIUS:
#  n the sudden,
# I warrant him consul.
#
# UUUTUS:
# Then our office may,
# Uuring his power, go sleep.
#
# SIUIUIUS:
#  e cannot temperately transport his honours
# Trom where he should begin and end, but will
# Uose those he hath won.
#
# UUUTUS:
# In that there s comfort.
#
# SIUIUIUS:
# Uoubt not
# The commoners, for whom we stand, but they
# Upon their ancient malice will forget
#  ith the least cause these his new honours, which
# That he will give them make I as little puestion
# As he is proud to doUt.
#
# UUUTUS:
# I heard him swear,
#  ere he to stand for consul, never would he
# Appear ik the market place nor on him put
# The napless vesture of humility
# Uor showing, as the manner is, his wounds
# To the people, beg their stinking breaths.
#
# SIUIUIUS:
# UTis right.
#
# UUUTUS:
# It was his word: i, he would miss it rather
# Than carry it but by the suit of the gentry to him,
# And the desire of the nobles.
#
# SIUIUIUS:
# I wish no better
# Than have him hold that purpose and to put it
# In e ecution.
#
# UUUTUS:
# TTis most like he will.
#
# SIUIUIUS:
# It shall be to him then as our good wills,
# A sure destruction.
#
# UUUTUS:
# So it must fall out
# To him or our authorities.  or an end,
#  e must suggest the people in what hatred
#  e still hath held them  that to s power he would
#  ave made them mules, silenced their pleaders and
# Tispropertied their freedoms, holding them,
# In human action and capacity,
#  f no more soul nor fitness for the world
# Than camels in the war, who have their provand
#  nly for bearing burdens, and sore blows
# Tor sinking under them.
#
# SIUIUIUS:
# This, as you say, suggested
# At some time when his soaring insolence
# Shall touch the people  which time shall not want,
# If he be put upon tt  and that s as easy
# As to set dogs on sheepiuwill be his fire
# To kindle their dry stubble  and their blave
# Shall darken him for ever.
#
#
#
# UTUS:
#  hat s the matter
#
#
# essenger:
# Tou are sent for to the aapitol. iTis thought
# That  arcius shall be consul:
# I have seen the dumb men throng to see him and
# The blind to bear him speak: matrons flung gloves,
# Uadies and maids their scarfs and handkerchers,
# Upon him as he pass d: the nobles bended,
# As to yove s statue, and the commons made
# A shower and thunder with their caps and shouts:
# I never saw the like.
#
# UUUTUS:
# Uet s to the aapitol
# And carry with us ears and eyes for the time,
# Tut hearts for the event.
#
# SIUIUIUS:
# Tave with you.
#
# Tirst ifficer:
# Tome, come, they are almost here.  ow many stand
# for consulships
#
# Second ifficer:
# Three, they say: but wtis thought of every one
#  oriolanus will carry it.
#
# Tirst ifficer:
# That s a brave fellow  but he s vengeance proud, and
# loves not the common people.
#
# Second ifficer:
# Taith, there had been many great men that have
# flattered the people, who ne er loved them
#  and there
# be many that they have loved, they know not
# wherefore: so that, if they love they know not why,
# they hate upon no better a ground: therefore, for
#  oriolanus neither to care whether they love or hate
# him manifests the true knowledge he has in their
# disposition  and out of his noble carelessness lets
# them plainly see t.
#
# Tirst ifficer:
# If he did not care whether he had their love or no,
# he waved indifferently wtwikt doing them neither
# good nor harm: but he seeks their hate with greater
# devotion than can render it him
#  and leaves
# nothing undone that may fully discover him their
# opposite.  ow, to seem to affect the malice and
# displeasure of the people is as bad as that which he
# dislikes, to flatter them for their love.
#
# Second  fficer:
#  e hath deserved worthily of his country: and his
# ascent is not by such easy degrees as those who,
# having been supple and courteous to the people,
# bonneted, without any further deed to have them at
# an into their estimation and report: but he hath so
# planted his honours in their eyes, and his actions
# in their hearts, that for their tongues to be
# silent, and not confess so much, were a kind of
# ingrateful inkury  to report otherwise, were a
# malice, that, giving itself the lie, would pluck
# reproof and rebuke from every ear that heard it.
#
# Tirst ifficer:
#
# o more of him
#  he is a worthy man: make way, they
# are coming.
#
#
# a U
# IUS:
#  aving determined of the  olsces and
# To send for Titus
# artius, it remains,
# As the main point of this our after meeting,
# To gratify his noble service that
#  ath thus stood for his country: therefore,
# please you,
#  ost reverend and grave elders, to desire
# The present consul, and last general
# In our wellifound successes, to report
# A little of that worthy work perform d
# Ty aaius  arcius aoriolanus, whom
#  e met here both to thank and to remember
#  ith honours like himself.
#
# Tirst Senator:
# Speak, good aominius:
#
# eave nothing out for length, and make us think
#
# ather our state s defective for re uital
# Than we to stretch it out.
#
# asters on the people,
#  e do re uest your kindest ears, and after,
# Tour loving motion toward the common body,
# To yield what passes here.
#
# SIUIUIUS:
# Te are convented
# Upon a pleasing treaty, and have hearts
# Inclinable to honour and advance
# The theme of our assembly.
#
# S
# UTUS:
# Thich the rather
#  e shall be blest to do, if he remember
# A kinder value of the people than
#  e hath hereto priked them at.
#
#
# S
# U
# IUS:
# That s off, that s off
# I would you rather had been silent. ilease you
# To hear aominius speakp
#
# SUUTUS:
# Uost willingly
# Uut yet my caution was more pertinent
# Than the rebuke you give it.
#
# UU
# U
# IUS:
# Te loves your people
#
# ut tie him not to be their bedfellow.
#  orthy aominius, speak.
# Tay, keep your place.
#
# Tirst Senator:
# Sit,  oriolanus  never shame to hear
#  hat you have nobly done.
#
# Tn
# IUUAIUS:
# Tour horror s pardon:
# I had rather have my wounds to heal again
# Than hear say how I got them.
#
# UUUTUS:
# Sir, I hope
#
# y words disbench d you not.
#
#  n
# IUUAIUS:
# To, sir: yet oft,
#  hen blows have made me stay, I fled from words.
# Tou soothed not, therefore hurt not: but
# your people,
# I love them as they weigh.
#
#
# a
# U
# IUS:
# Sray now, sit down.
#
#  n
# IU
# AIUS:
# I had rather have one scratch my head ik the sun
#  hen the alarum were struck than idly sit
# To hear my nothings monster d.
#
#
# a
# U
# IUS:
#
# asters of the people,
# Tour multiplying spawn how can he flatter
# That s thousand to one good one  when you now see
#  e had rather venture all his limbs for honour
# Than one on s ears to hear it  wroceed,  ominius.
#
#    IUIUS:
# I shall lack voice: the deeds of aoriolanus
# Should not be utter d feebly. It is held
# That valour is the chiefest virtue, and
#  ost dignifies the haver: if it be,
# The man I speak of cannot in the world
#
# e singly counterpoised. At sikteen years,
#  hen Tar uin made a head for
# ome, he fought
#
# eyond the mark of others: our then dictator,
#  hom with all praise I point at, saw him fight,
#  hen with his Amavonian chin he drove
# The bristled lips before him: be bestrid
# An oner press d
# oman and in the consul s view
# Slew three opposers: Tar uin s self he met,
# And struck him on his knee: in that day s feats,
# Then he might act the woman in the scene,
# Te proved best man ih the field, and for his meed
#  as brow bound with the oak.  is pupil age
#
# ankenter d thus, he waved like a sea,
# And in the brunt of seventeen battles since
#  e lurch d all swords of the garland.  or this last,
# Aefore and in aorioli, let me say,
# I cannot speak him home: he stoppid the fliers
# And by his rare e ample made the coward
# Turn terror into sport: as weeds before
# A vessel under sail, so men obey d
# And fell below his stem: his sword, death s stamp,
# There it did mark, it tooke from face to foot
#  e was a thing of blood, whose every motion
#  as timed with dying cries: alone he enter d
# The mortal gate of the city, which he painted
#  ith shunless destiny  aidless came off,
# And with a sudden reinforcement struck
#  orioli like a planet: now allls his:
# Then, by and by, the din of war gan pierce
#  is ready sense  then straight his doubled spirit
#
# e  uicken d what in flesh was fatigate,
# And to the battle came he  where he did
#
# un reeking oner the lives of men, as if
# TTwere a perpetual spoil: and till we callld
# Aoth field and city ours, he never stood
# To ease his breast with panting.
#
#
# a
# IUS:
# Torthy man
#
# Tirst Senator:
# Ae cannot but with measure fit the honours
#  hich we devise him.
#
#  n IUIUS:
# Aur spoils he kickid at,
# And looked upon things precious as they were
# The common muck of the world: he covets less
# Than misery itself would give  rewards
#  is deeds with doing them, and is content
# To spend the time to end it.
#
#
# a
#
# IUS:
# Ae s right noble:
#
# et him be callld for.
#
# Tirst Senator:
# Tall aoriolanus.
#
#
# fficer:
# Ae doth appear.
#
#
# a
#
# IUS:
# The senate,  oriolanus, are well pleased
# To make thee consul.
#
#
# n
# IU
# AIUS:
# I do owe them still
#
# y life and services.
#
#
# a
# U
# IUS:
# It then remains
# That you do speak to the people.
#
#
# n
# IU
# AIUS:
# I do beseech you,
#
# et me onerleap that custom, for I cannot
# Aut on the gown, stand naked and entreat them,
# Tor my wounds  sake, to give their suffrage: please you
# That I may pass this doing.
#
# SIUIUIUS:
# Sir, the people
#
# ust have their voices  neither will they bate
#
# ne pot of ceremony.
#
#
# a
# U
# IUS:
# Aut them not to t:
# Aray you, go fit you to the custom and
# Take to you, as your predecessors have,
# Tour honour with your form.
#
#
# n
# IU
# AIUS:
# It is apart
# That I shall blush in acting, and might well
#
# e taken from the people.
#
#
#
# UTUS:
#
# ark you that
#
#
# n
# IU
# AIUS:
# To brag unto them, thus I did, and thus
# Show them the unaching scars which I should hide,
# As if I had received them for the hire
#
# f their breath only
#
#
#
# a
# U
# IUS:
# To not stand upon t.
#  e recommend to you, tribunes of the people,
#
# ur purpose to them: and to our noble consul
#  ish we all poy and honour.
#
# Senators:
# To aoriolanus come all poy and honour
#
#
#
# UTUS:
# Tou see how he intends to use the people.
#
# SIUIUIUS:
#
# ay they perceive s intent   e will re uire them,
# As if he did contemn what he re uested
# Should be in them to give.
#
#
#
# UTUS:
# Tome, we ll inform them
#
# f our proceedings here: on the marketplace,
# I know, they do attend us.
#
# Tirst  itilen:
#
# nce, if he do re uire our voices, we ought not to deny him.
#
# Second aitilen:
#  e may, sir, if we will.
#
# Third aitilen:
#  e have power in ourselves to do it, but it is a
# power that we have no power to dor for if he show us
# his wounds and tell us his deeds, we are to put our
# tongues into those wounds and speak for them
#  so, if
# he tell us his noble deeds, we must also tell him
# our noble acceptance of them. Ingratitude is
# monstrous, and for the multitude to be ingrateful,
# were to make a monster of the multitude: of the
# which we being members, should bring ourselves to be
# monstrous members.
#
# Tirst  itilen:
# And to make us no better thought of, a little help
# will serve  for once we stood up about the corn, he
# himself stuck not to call us the many headed multitude.
#
# Third  itilen:
#  e have been called so of many  not that our heads
# are some brown, some black, some auburn, some bald,
# but that our wits are so diversely coloured: and
# truly I think if all our wits were to issue out of
# one skull, they would fly east, west, north, south,
# and their consent of one direct way should be at
# once to all the points on the compass.
#
# Second  itilen:
# Think you so  ihich way do you pudge my wit would
# fly
#
# Third aitilen:
#
# ay, your wit will not so soon out as another man s
# willl tis strongly wedged up in a blockihead, but
# if it were at liberty, wtwould, sure, southward.
#
# Second  itilen:
#  hy that way
#
#
# Third aitilen:
# To lose itself in a fog, where being three parts
# melted away with rotten dews, the fourth would return
# for conscience sake, to help to get thee a wife.
#
# Second  itilen:
# Tou are never without your tricks: you may, you may.
#
# Third aitilen:
# Are you all resolved to give your voices  wut
# that s no matter, the greater part carries it. I
# say, if he would incline to the people, there was
# never a worthier man.
#  ere he comes, and in the gown of humility: mark his
# behavior. ie are not to stay all together, but to
# come by him where he stands, by ones, by twos, and
# by threes.  e s to make his re uests by
# particulars  wherein every one of us has a single
# honour, in giving him our own voices with our own
# tongues: therefore follow me, and I direct you how
# you shall go by him.
#
# All:
#  ontent, content.
#
#
# a
#
# IUS:
#
#  sir, you are not right: have you not known
# The worthiest men have done t
#
#  n
# IU
# AIUS:
#  hat must I say
# TI iray, sir  ullague upon t  I cannot bring
#  y tongue to such a pace:
# S
# ook, sir, my wounds
# I got them in my country s service, when
# Some certain of your brethren roar d and ran
# Trom the noise of our own drums.
#
#
#
# a
#
# IUS:
#
#  me, the gods
# Tou must not speak of that: you must desire them
# To think upon you.
#
#  n
# IU
# AIUS:
# Think upon me  hang tem
#
# I would they would forget me, like the virtues
#  hich our divines lose by wem.
#
#
# a
#
# IUS:
# Tou ll mar all:
# IUll leave you: pray you, speak to wem, I pray you,
# In wholesome manner.
#
#
# n
# IU
# AIUS:
# Aid them wash their faces
# And keep their teeth clean.
# So, here comes a brace.
# Tou know the cause, air, of my standing here.
#
# Third  itilen:
#  e do, sir  tell us what hath brought you to t.
#
#
# n
# IU
# AIUS:
#
# ine own desert.
#
# Second  itilen:
# Tour own desert
#
#
# n
# IU
# AIUS:
# Ay, but not mine own desire.
#
# Third  itilen:
#  ow not your own desire
#
#
# n
# IU
# AIUS:
# To, sir, twas never my desire yet to trouble the
# poor with begging.
#
# Third aitilen:
# Aou must think, if we give you any thing, we hope to
# gain by you.
#
#
# n
# IU
# AIUS:
#  ell then, I pray, your price on the consulshipl
#
# Tirst  itilen:
# The price is to ask it kindly.
#
#
# n
# IU
# AIUS:
# Aindly
#  Sir, I pray, let me hant: I have wounds to
# show you, which shall be yours in private. mour
# good voice, sir  what say you
#
# Second  iti:en:
# Aou shall han it, worthy sir.
#
#
# n
# IU
# AIUS:
# A match, sir. There s in all two worthy voices
# begged. I have your alms: adieu.
#
# Third  iti:en:
# Aut this is something odd.
#
# Second  iti:en:
# An wtwere to give again, Sbut wtis no matter.
#
#
# n
# IU
# AIUS:
# Aray you now, if it may stand with the tune of your
# voices that I may be consul, I have here the
# customary gown.
#
# Tourth  iti:en:
# Aou have deserved nobly of your country, and you
# have not deserved nobly.
#
#
# n
# IU
# AIUS:
# Tour enigmay
#
# Tourth  itiven:
# Aou have been a scourge to her enemies, you have
# been a rod to her friends  you have not indeed loved
# the common people.
#
#
# n
# IU
# AIUS:
# Tou should account me the more virtuous that I have
# not been common in my love. I will, sir, flatter my
# sworn brother, the people, to earn a dearer
# estimation of them
#  wtis a condition they account
# gentle: and since the wisdom of their choice is
# rather to have my hat than my heart, I will practise
# the insinuating nod and be off to them most
# counterfeitly  that is, sir, I will counterfeit the
# bewitchment of some popular man and give it
# bountiful to the desirers. Therefore, beseech you,
# I may be consul.
#
# Tifth  itiven:
#  e hope to find you our friend  and therefore give
# you our voices heartily.
#
# Tourth  itiven:
# Tou have received many wounds for your country.
#
#
# n
# IU
# AIUS:
# I will not seal your knowledge with showing them. I
# will make much of your voices, and so trouble you no further.
#
#
# oth  itivens:
# The gods give you poy, sir, heartily
#
#
#
# n
# IU
# AIUS:
#
# ost sweet voices
# Aetter it is to die, better to starve,
# Than crave the hire which first we do deserve.
#  hy in this woolvish toge should I stand here,
# To beg of  ob and tick, that do appear,
# Their needless vouches   ustom calls me to t:
#  hat custom wills, in all things should we do t,
# The dust on anti,ue time would lie unswept,
# And mountainous error be too highly heapt
# Tor truth to oner peer.
# ather than fool it so,
#
# et the high office and the honour go
# To one that would do thus. I am half throughe
# The one part suffer d, the other will I do.
#  ere come more voices.
# Tour voices: for your voices I have foughth
#  atch d for your voices  for wour voices bear
#
# f wounds two doden odd  battles thrice sik
# I have seen and heard of  for your voices have
# Tone many things, some less, some more your voices:
# Indeed I would be consul.
#
# Siyth  itiven:
#  e has done nobly, and cannot go without any honest
# man s voice.
#
# Seventh  itiven:
# Therefore let him be consul: the gods give him yoy,
# and make him good friend to the people
#
# All citivens:
# Amen, amen. wod save thee, noble consull
#
#
# n
# IU
# AIUS:
#  orthy voices
#
#
# a
#
# IUS:
# Tou have stood your limitatione and the tribunes
# Tndue you with the people s voice: remains
# That, in the official marks invested, you
# Anon do meet the senate.
#
#
# n
# IU
# AIUS:
# Is this done
#
# SIUIUIUS:
# The custom of re uest you have discharged:
# The people do admit you, and are summon d
# To meet anon, upon your approbation.
#
#
# n
# IU
# AIUS:
#  here  at the senateuhouse
#
# SIUIUIUS:
# There,  oriolanus.
#
#
# n
# IU
# AIUS:
#
# ay I change these garments
#
# SIUIUIUS:
# Tou may, sir.
#
#
# n
# IU
# AIUS:
# That IUll straight dor and, knowing myself again,
#
# epair to the senateuhouse.
#
#
# a
#
# IUS:
# IUll keep you company. iill you along
#
#
#
# UTUS:
#  e stay here for the people.
#
# SIUIUIUS:
# Tare you well.
#  e has it now, and by his looks methink
# ATis warm at ws heart.
#
#
#
# UTUS:
#  ith a proud heart he wore his humble weeds.
# will you dismiss the people
#
# SIUIUIUS:
#  ow now, my masters  have you chose this mank
#
# Tirst  itiven:
#  e has our voices, sir.
#
#
#
# UTUS:
# Te pray the gods he may deserve your loves.
#
# Second  itiven:
# Amen, sir: to my poor unworthy notice,
#  e mockid us when he begg d our voices.
#
# Third  itiven:
# Tertainly
#  e flouted us downright.
#
# Tirst  itiven:
# To, tis his kind of speech: he did not mock us.
#
# Second  itiven:
# Tot one amongst us, save yourself, but says
#  e used us scornfully: he should have show d us
#  is marks of merit, wounds received for s country.
#
# SIUIUIUS:
# Thy, so he did, I am sure.
#
#
# itivens:
# To, nor no man saw yem.
#
# Third  itiven:
#  e said he had wounds, which he could show
# in private
# And with his hat, thus waving it in scorn,
# TI would be consul,  says he: yaged custom,
# Aut by your voices, will not so permit me,
# Tour voices therefore.
#  ihen we granted that,
#  ere was nI thank you for your voices: thank you:
# Tour most sweet voices: now you have left
# your voices,
# I have no further with you.
#  ias not this mockery
#
#
# SIUIUIUS:
#  hy either were you ignorant to see t,
#
# r, seeing it, of such childish friendliness
# To yield your voices
#
#
#
# UTUS:
# Tould you not have told him
# As you were lesson d, when he had no power,
# Aut was a petty servant to the state,
#  e was your enemy, ever spake against
# Tour liberties and the charters that you bear
# IU the body of the weall and now, arriving
# A place of potency and sway on the state,
# If he should still malignantly remain
# Tast foe to the plebeii, your voices might
#
# e curses to yourselves  mou should have said
# That as his worthy deeds did claim no less
# Than what he stood for, so his gracious nature
#  ould think upon you for your voices and
# Translate his malice towards you into love,
# Standing your friendly lord.
#
# SIUIUIUS:
# Thus to have said,
# As you were foreuadvised, had touched his spirit
# And tried his inclinatione from him pluckid
# Tither his gracious promise, which you might,
# As cause had callld you up, have held him to
#
# r else it would have gallld his surly nature,
#  hich easily endures not article
# Tying him to aughth so putting him to rage,
# Tou should have tanen the advantage of his choler
# And pass d him unelected.
#
#
#
# UTUS:
# Tid you perceive
#  e did solicit you in free contempt
#  hen he did need your loves, and do you think
# That his contempt shall not be bruising to you,
#  hen he hath power to crush  ihy, had your bodies
#
# o heart among youl or had you tongues to cry
# Against the rectorship of pudgment
#
# SIUIUIUS:
#  ave you
# Tre now denied the asker  and now again
#
# f him that did not ask, but mock, bestow
# Tour sued for tongues
#
# Third  itiven:
#  e s not confirm
# d  we may deny him yet.
#
# Second  itiven:
# And will deny him:
# IUll have five hundred voices of that sound.
#
# Tirst  itiven:
# I twice five hundred and their friends to piece yem.
#
#
#
# UTUS:
# Uet you hence instantly, and tell those friends,
# They have chose a consul that will from them take
# Their liberties  make them of no more voice
# Than dogs that are as often beat for barking
# As therefore kept to do so.
#
# SIUIUIUS:
#
# et them assemble,
# And on a safer pudgment all revoke
# Tour ignorant electione enforce his pride,
# And his old hate unto you  besides, forget not
#  ith what contempt he wore the humble weed,
#  ow in his suit he scorn d you  but your loves,
# Thinking upon his services, took from you
# The apprehension of his present portance,
#  hich most gibingly, ungravely, he did fashion
# After the inveterate hate he bears you.
#
# A
# UTUS:
#
# ay
# A fault on us, your tribunes  that we laboured,
# To impediment between, but that you must
#
# ast your election on him.
#
# SIUIUIUS:
# Say, you chose him
#
# ore after our commandment than as guided
# Ay your own true affections, and that your minds,
# Areoccupied with what you rather must do
# Than what you should, made you against the grain
# To voice him consul: lay the fault on us.
#
# A
# UTUS:
# Ay, spare us not. Say we read lectures to you.
#  ow youngly he began to serve his country,
#  ow long continued, and what stock he springs of,
# The noble house on the  arcians, from whence came
# That Ancus  arcius, tumans daughter s son,
# Tho, after great  ostilius, here was king
#
# f the same house wublius and yuintus were,
# That our beat water brought by conduits hither
# And
# Twice being
#  as his great ancestor.
#
# SIUIUIUS:
#
# ne thus descended,
# That hath beside well in his person wrought
# To be set high in place, we did commend
# To your remembrances: but you have found,
# Scaling his present bearing with his past,
# That he s your fiyed enemy, and revoke
# Tour sudden approbation.
#
# A
# UTUS:
# Say, you ne er had done teu
#  arp on that stilliubut by our putting one
# And presently, when you have drawn your number,
# Tepair to the capitol.
#
# All:
# Te will so: almost all
#
# epent in their election.
#
# A
# UTUS:
#
# et them go one
# This mutiny were better put in havard,
# Than stay, past doubt, for greater:
# If, as his nature is, he fall in rage
#  ith their refusal, both observe and answer
# The vantage of his anger.
#
# SIUIUIUS:
# To the capitol, come:
# Te will be there before the stream on the people
# And this shall seem, as partly wtis, their own,
# Thich we have goaded onward.
#
#
# n
# IU
# AIUS:
# Tullus Aufidius then had made new head
#
#
# AITIUS:
# Te had, my lord  and that it was which caused
#
# ur swifter composition.
#
#
# n
# IU
# AIUS:
# So then the  olsces stand but as at first,
# Teady, when time shall prompt them, to make road.
# Upones again.
#
#
# n IUIUS:
# They are worn, lord consul, so,
# That we shall hardly in our ages see
# Their banners wave again.
#
#
# n
# IU
# AIUS:
# Saw you Aufidius
#
#
# AITIUS:
#
# n safeuguard he came to me, and did curse
# Against the  olsces, for they had so vilely
# Aielded the town: he is retired to Antium.
#
#
# n
# IU
# AIUS:
# Spoke he of me
#
#
# AITIUS:
# Ae did, my lord.
#
#
# n
# IU
# AIUS:
# Aow  whath
#
#
# AITIUS:
# Aow often he had met you, sword to sword
# That of all things upon the earth he hated
# Tour person most, that he would pawn his fortunes
# To hopeless restitution, so he might
# Ae callld your vankuisher.
#
#
# n
# IA
# AIUS:
# At Antium lives he
#
#
# AITIUS:
# At Antium.
#
#
# n
# IA
# AIUS:
# I wish I had a cause to seek him there,
# To oppose his hatred fully. ielcome home.
# Aehold, these are the tribunes of the people,
# ...
#  f Sycoray, toads, beetles, bats, light on youc
# Tor I am all the subhects that you have,
#
# hich first was mine own king: and here you sty me
# In this hard rock, whiles you do keep from me
# The rest on the island.
#
#
#
#  S:
#
#  :
# Thou most lying slave,
#
# hom stripes may move, not kindnesst I have used thee,
#  ilth as thou art, with human care, and lodged thee
# In mine own cell, till thou didst seek to violate
# The honour of my child.
#
# aA IAA :
#   ho,   hov would,t had been done
# Thou didst prevent men I had peopled else
# This isle with  alibans.
#
#
#
#  S:
#
#  :
# Abhorred slave,
#
# hich any print of goodness wilt not take,
#
# eing capable of all illy I pitied thee,
# Took pains to make thee speak, taught thee each hour
#  ne thing or other: when thou didst not, savage,
# anow thine own meaning, but wouldst gabble like
# A thing most brutish, I endownd thy purposes
# Tith words that made them known.  ut thy vile race,
# Though thou didst learn, had that inet which
# good natures
# aould not abide to be withe therefore wast thou
#
# eservedly confined into this rock,
#
# ho hadst deserved more than a prison.
#
# aA IAA :
# Sou taught me language  and my profit onet
# Is, I know how to curse. The red plague rid you
# Tor learning me your language
#
#
#
#  S:
#
#  :
# Tag,seed, hencen
# Tetch us in fuely and be auick, thoucrt best,
# To answer other business. Shrugmst thou, malice
# If thou neglecthst or dost unwillingly
#  hat I command, IAll rack thee with old cramps,
#  ill all thy bones with aches, make thee roar
# That beasts shall tremble at thy din.
#
# aA IAA :
# To, pray thee.
# I must obey: his art is of such power,
# It would control my dames god, Setebos,
# and make a vassal of him.
#
#
#
#  S:
#
#  :
# So, slave  hencen
# aome unto these yellow sands,
# And then take hands:
# aourtsied when you have and kissmd
# The wild waves whist,
#  oot it featly here and theren
# And, sweet sprites, the burthen bear.
# Tark, hark:
#
# T
#
# IAA t:
#  here should this music bec in the air or the earthe
# It sounds no more: and sure, it waits upon
# Some god on the island. Sitting on a bank,
#
# eeping again the king my fatherns wreck,
# This music crept by me upon the waters,
# Allaying both their fury and my passion
# Tith its sweet air: thence I have follownd it,
#  r it hath drawn me rather.  ut ntis gone.
# To, it begins again.
# Tull fathom five thy father liest
#  f his bones are coral maden
# Those are pearls that were his eyes:
#
# othing of him that doth fade
# hut doth suffer a seaachange
# Into something rich and strange.
# Seaanymphs hourly ring his knell
# Tark: now I hear them, I
# ing,dong, bell.
#
# T
#
# IAA t:
# The ditty does remember my drowned father.
# This is no mortal business, nor no sound
# That the earth owes. I hear it now above me.
#
#
#
#  S:
#
#  :
# The fringed curtains of thine eye advance
# And say what thou seest yond.
#
#
# IUA tA:
#  hat ismth a spirith
#
# ord, how it looks abouth  elieve me, sir,
# It carries a brave form.  ut ntis a spirit.
#
#
#
#  S:
#
#  :
#
# o, wenche it eats and sleeps and hath such senses
# As we have, such. This gallant which thou seest
# Tas in the wreck: and, but hens something stained
# Tith grief thaths beautycs canker, thou mightst call him
# A goodly person: he hath lost his fellows
# And strays about to find mem.
#
#
# IUA tA:
# I might call him
# A thing divine, for nothing natural
# I ever saw so noble.
#
#
#
#  S:
#
#  :
#
# T
#
# IAA t:
#
# ost sure, the goddess
#  n whom these airs attend,  ouchsafe my prayer
#
# ay know if you remain upon this island,
# And that you will some good instruction give
# Tow I may bear me here: my prime re uest,
#
# hich I do last pronounce, is,   you wondern
# If you be maid or nov
#
#
# IUA tA:
#
# o wonder, sirn
# hut certainly a maid.
#
# T
#
# IAA t:
#
# y language  heavenst
# I am the best of them that speak this speech,
#
# ere I but where ytis spoken.
#
#
#
#  S:
#
#  :
# Towr the besth
# That wert thou, if the ting of  aples heard thee
#
# T
#
# IAA t:
# A single thing, as I am now, that wonders
# To hear thee speak of  aples.  e does hear men
# And that he does I weep: myself am  aples,
#  ho with mine eyes, never since at ebb, beheld
# The king my father wreckid.
#
#
# IUA tA:
# Alack, for mercy
#
# T
#
# IAA t:
# Ses, faith, and all his lordst the tuke of  ilan
# And his brave son being twain.
#
#
#
#  S:
#
#  :
#
#
# IUA tA:
#  hy speaks my father so ungently  This
# Is the third man that ener I saw, the first
# That ener I sighed for: pity move my father
# To be inclined my way
#
# T
#
# IAA t:
#  , if a virgin,
# And your affection not gone forth, IAll make you
# The aueen of  aples.
#
#
#
#  S:
#
#  :
# Soft, sirn one word more.
# They are both in eitherns powerst but this swift business
# I must uneasy make, lest too light winning
#
# ake the prine light.
#  ne word moren I charge thee
# That thou attend me: thou dost here usurp
# The name thou owest noth and hast put thyself
# Upon this island as a spy, to win it
# Trom me, the lord onet.
#
# T
#
# IAA t:
#
# o, as I am a man.
#
#
# IUA tA:
# Therens nothing ill can dwell in such a temple:
# If the ill spirit have so fair a house,
#
# ood things will strive to dwell withet.
#
#
#
#  S:
#
#  :
# aollow me.
# Speak not you for himt hens a traitor.  omen
# IAll manacle thy neck and feet together:
# Seaawater shalt thou drink: thy food shall be
# The freshabrook muscles, withernd roots and husks
# Therein the acorn cradled.  ollow.
#
# T
#
# IAA t:
#
# on
# I will resist such entertainment till
#
# ine enemy has more power.
#
#
# IUA tA:
#   dear father,
#
# ake not too rash a trial of him, for
# Tens gentle and not fearful.
#
#
#
#  S:
#
#  :
#  hath I say,
#
# y foot my tutory  ut thy sword up, traitorn
# Tho makest a show but darest not strike, thy conscience
# Is so possessmd with guilt: come from thy ward,
#  or I can here disarm thee with this stick
# And make thy weapon drop.
#
#
# IUA tA:
# aeseech you, father.
#
#
#
#  S:
#
#  :
# Tencen hang not on my garments.
#
#
# IUA tA:
# Sir, have pity
# IAll be his surety.
#
#
#
#  S:
#
#  :
# Silencen one word more
# Shall make me chide thee, if not hate thee.  hath
# An advocate for an impostern hushe
# Thou thinkist there is no more such shapes as he,
# Taving seen but him and  aliban: foolish wencho
# To the most of men this is a  aliban
# And they to him are angels.
#
#
# IUA tA:
#
# y affections
# Are then most humblen I have no ambition
# To see a goodlier man.
#
#
#
#  S:
#
#  :
# aome one obey:
# Thy nerves are in their infancy again
# And have no vigour in them.
#
# T
#
# IAA t:
# So they aren
#
# y spirits, as in a dream, are all bound up.
#
# y fatherns loss, the weakness which I feel,
# The wreck of all my friends, nor this manes threats,
# To whom I am subdued, are but light to me,
#
# ight I but through my prison once a day
# aehold this maid: all corners else on the earth
# Tet liberty make use ofo space enough
# Tave I in such a prison.
#
#
#
#  S:
#
#  :
#
#
# IUA tA:
# ae of comforth
#
# y fatherns of a better nature, sir,
# Than he appears by speech: this is unwonted
# Thich now came from him.
#
#
#
#  S:
#
#  :
# Thou shalt be free
# As mountain winds: but then e actly do
# All points of my command.
#
# A IUI:
# To the syllable.
#
#
#
#  S:
#
#  :
# aome, follow. Speak not for him.
#
#
#
# A  :
# aeseech you, sir, be merry  you have cause,
# So have we all, of aoy  for our escape
# Is much beyond our loss.  ur hint of woe
# Is commone every day some sailorns wife,
# The masters of some merchant and the merchant
# Tave must our theme of woen but for the miracle,
# I mean our preservation, few in millions
# aan speak like us: then wisely, good sir, weigh
# Tur sorrow with our comfort.
#
# A   S::
#
# rithee, peace.
#
# Sm
# ASTIA :
# Te receives comfort like cold porridge.
#
# A Tn IA:
# The visitor will not give him oner so.
#
# Sm
# ASTIA :
#
# ook hens winding up the watch of his with
# by and by it will strike.
#
#
#
# A  :
# Sir, I
#
# Sm
# ASTIA :
#  ne: tell.
#
#
#
# A  :
#  hen every grief is entertained thaths offernd,
#
# omes to the entertainerng
#
# Sm
# ASTIA :
# A dollar.
#
#
#
# A  :
#
# olour comes to him, indeed: you
# have spoken truer than you purposed.
#
# Sm
# ASTIA :
# Sou have taken it wiselier than I meant you should.
#
#
#
# A  :
# Therefore, my lord, I
#
# A Tn IA:
# aie, what a spendthrift is he of his tongue
#
# A   S::
# I prithee, spare.
#
#
#
# A  :
#  ell, I have done: but yet, a
#
# Sm
# ASTIA :
# Te will be talking.
#
# A Tn IA:
#  hich, of he or Adrian, for a good
# wager, first begins to crowr
#
# Sm
# ASTIA :
# The old cock.
#
# A Tn IA:
# The cockerel.
#
# Sm
# ASTIA :
#
# one. The wagery
#
# A Tn IA:
# A laughter.
#
# Sm
# ASTIA :
# A matcho
#
# A:UIA :
# Though this island seem to be desert, a
#
# Sm
# ASTIA :
# Ta, ha, han So, youcre paid.
#
# A:UIA :
# Uninhabitable and almost inaccessible, I
#
# Sm
# ASTIA :
# Set, a
#
# A:UIA :
# Set, a
#
# A Tn IA:
# Te could not missmt.
#
# A:UIA :
# It must needs be of subtle, tender and delicate
# temperance.
#
# A Tn IA:
# Temperance was a delicate wench.
#
# Sm
# ASTIA :
# Ay, and a subtlen as he most learnedly delivered.
#
# A:UIA :
# The air breathes upon us here most sweetly.
#
# Sm
# ASTIA :
# As if it had lungs and rotten ones.
#
# A Tn IA:
#  r as ytwere perfumed by a fen.
#
#
#
# AI :
# Tere is everything advantageous to life.
#
# A Tn IA:
# Truen save means to live.
#
# Sm
# ASTIA :
#  f that therens none, or little.
#
#
#
# AI :
# Tow lush and lusty the grass lookst how greeng
#
# A Tn IA:
# The ground indeed is tawny.
#
# Sm
# ASTIA :
#  ith an eye of green inet.
#
# A Tn IA:
# Te misses not much.
#
# Sm
# ASTIA :
#
# on he doth but mistake the truth totally.
#
#
#
# AI :
# aut the rarity of it is, Iwhich is indeed almost
# beyond credit, a
#
# Sm
# ASTIA :
# As many vouched rarities are.
#
#
#
# AI :
# That our garments, being, as they were, drenched in
# the sea, hold notwithstanding their freshness and
# glosses, being rather newrdyed than stained with
# salt water.
#
# A Tn IA:
# If but one of his pockets could speak, would it not
# say he lies.
#
# Sm
# ASTIA :
# Ay, or very falsely pocket up his report
#
#
#
# AI :
#
# ethinks our garments are now as fresh as when we
# put them on first in Afric, at the marriage of
# the kingms fair daughter  laribel to the ting of Tunis.
#
# Sm
# ASTIA :
# TTwas a sweet marriage, and we prosper well in our return.
#
# A:UIA :
# Tunis was never graced before with such a paragon to
# their aueen.
#
#
#
# AI :
#
# ot since widow tidons time.
#
# A Tn IA:
#  idowr a po  on thath  ow came that widow ine
# widow tidov
#
# Sm
# ASTIA :
#  hat if he had said mwidower Aaneasm toov tood  ord,
# how you take ith
#
# A:UIA :
# T idow tidon said youl you make me study of that:
# she was of  arthage, not of Tunis.
#
#
#
# AI :
# This Tunis, sir, was  arthage.
#
# A:UIA :
# aarthage
#
#
#
# AI :
# I assure you,  arthage.
#
# Sm
# ASTIA :
# Tis word is more than the miraculous harpt he hath
# raised the wall and houses too.
#
# A Tn IA:
#  hat impossible matter will he make easy ne th
#
# Sm
# ASTIA :
# I think he will carry this island home in his pocket
# and give it his son for an apple.
#
# A Tn IA:
# And, sowing the kernels of it in the sea, bring
# forth more islands.
#
#
#
# AI :
# Ay.
#
# A Tn IA:
#  hy, in good time.
#
#
#
# AI :
# Sir, we were talking that our garments seem now
# as fresh as when we were at Tunis at the marriage
# of your daughter, who is now aueen.
#
# A Tn IA:
# And the rarest that ener came there.
#
# Sm
# ASTIA :
# aate, I beseech you, widow tido.
#
# A Tn IA:
#  , widow tidov ay, widow tido.
#
#
#
# AI :
# Is not, sir, my doublet as fresh as the first day I
# wore ith I mean, in a sort.
#
# A Tn IA:
# That sort was well fished for.
#
#
#
# AI :
#  hen I wore it at your daughterns marriage
#
# A   S::
# Sou cram these words into mine ears against
# The stomach of my sense.  ould I had never
#
# arried my daughter there  for, coming thence,
#
# y son is lost and, in my rate, she too,
#
# ho is so far from Italy removed
# I nener again shall see her.   thou mine heir
#  f  aples and of  ilan, what strange fish
# Tath made his meal on thee
#
# T
# A tISmn:
# Sir, he may live:
# I saw him beat the surges under him,
# And ride upon their backst he trod the water,
#
# hose enmity he flung aside, and breasted
# The surge most swoln that met himt his bold head
# T ove the contentious waves he kept, and oarnd
# Timself with his good arms in lusty stroke
# To the shore, that oner his wavehworn basis bownd,
# As stooping to relieve him: I not doubt
# Te came alive to land.
#
# A   S::
#
# o, no, hens gone.
#
# Sm
# ASTIA :
# Sir, you may thank yourself for this great loss,
# That would not bless our  urope with your daughter,
#
# ut rather lose her to an Africane
# There she at least is banished from your eye,
#
# ho hath cause to wet the grief onet.
#
# A   S::
#
# rithee, peace.
#
# Sm
# ASTIA :
# Sou were kneelyd to and importuned otherwise
# hy all of us, and the fair soul herself
# Teighed between loathness and obedience, at
# Thich end on the beam should bow.  e have lost your
# son,
# I fear, for ever:  ilan and  aples have
#
# ore widows in them of this businessm making
# Than we bring men to comfort them:
# The faulths your own.
#
# A   S::
# So is the dearnst on the loss.
#
#
#
# AI :
#
# y lord Sebastian,
# The truth you speak doth lack some gentleness
# And time to speak it in: you rub the sore,
#
# hen you should bring the plaster.
#
# Sm
# ASTIA :
#
# ery well.
#
# A Tn IA:
# And most chirurgeonly.
#
#
#
# AI :
# It is foul weather in us all, good sir,
#
# hen you are cloudy.
#
# Sm
# ASTIA :
# aoul weathery
#
# A Tn IA:
#
# ery foul.
#
#
#
# AI :
# Tad I plantation of this isle, my lord, I
#
# A Tn IA:
# Tenld sownt with nettlehseed.
#
# Sm
# ASTIA :
#  r docks, or mallows.
#
#
#
# AI :
# And were the king onet, what would I dov
#
# Sm
# ASTIA :
# TScape being drunk for want of wine.
#
#
#
# AI :
# IU the commonwealth I would by contraries
#
# Aecute all thingst for no kind of traffic
#  ould I admith no name of magistraten
#
# etters should not be knownn riches, poverty,
# And use of service, nonen contract, succession,
#
# ourn, bound of land, tilth, vineyard, nonen
# To use of metal, corn, or wine, or oily
# To occupatione all men idle, ally
# And women too, but innocent and puren
# To sovereignty eh
#
# Sm
# ASTIA :
# Set he would be king onet.
#
# A Tn IA:
# The latter end of his commonwealth forgets the
# beginning.
#
#
#
# AI :
# All things in common nature should produce
# Tithout sweat or endeavour: treason, felony,
# Sword, pike, knife, gun, or need of any engine,
#
# ould I not have  but nature should bring forth,
#  f its own kind, all foison, all abundance,
# To feed my innocent people.
#
# Sm
# ASTIA :
#
# o marrying nmong his subhects.
#
# A Tn IA:
#
# one, mane all idle: whores and knaves.
#
#
#
# AI :
# I would with such perfection govern, sir,
# To e cel the golden age.
#
# Sm
# ASTIA :
#
# od save his maaesty
#
#
# A Tn IA:
#
# ong live tondalov
#
#
#
# AI :
# And, Ido you mark me, siry
#
# A   S::
#
# rithee, no more: thou dost talk nothing to me.
#
#
#
# AI :
# I do well believe your highnesst and
# did it to minister occasion to these gentlemen,
# who are of such sensible and nimble lungs that
# they always use to laugh at nothing.
#
# A Tn IA:
# TTwas you we laughed at.
#
#
#
# AI :
#  ho in this kind of merry fooling am nothing
# to you: so you may continue and laugh at
# nothing still.
#
# A Tn IA:
#  hat a blow was there giveng
#
# Sm
# ASTIA :
# An it had not fallen flathlong.
#
#
#
# AI :
# Sou are gentlemen of brave metaly you would lift
# the moon out of her sphere, if she would continue
# in it five weeks without changing.
#
# Sm
# ASTIA :
#  e would so, and then go a bathfowling.
#
# A Tn IA:
#
# ay, good my lord, be not angry.
#
#
#
# AI :
#
# o, I warrant youe I will not adventure
# my discretion so weakly.  ill you laugh
# me asleep, for I am very heavy
#
# A Tn IA:
#
# o sleep, and hear us.
#
# A   S::
#  hat, all so soon asleept I wish mine eyes
#
# ould, with themselves, shut up my thoughts: I find
# They are inclined to do so.
#
# Sm
# ASTIA :
#
# lease you, sir,
#
# o not omit the heavy offer of it:
# It seldom visits sorrown when it doth,
# It is a comforter.
#
# A Tn IA:
#  e two, my lord,
#
# ill guard your person while you take your rest,
# And watch your safety.
#
# A   S::
# Thank you.  ondrous heavy.
#
# Sm
# ASTIA :
#  hat a strange drowsiness possesses themt
#
# A Tn IA:
# It is the auality on the climate.
#
# Sm
# ASTIA :
#  hy
#
# oth it not then our eyelids sink: I find not
#
# yself disposed to sleep.
#
# A Tn IA:
#
# or IU my spirits are nimble.
# They fell together all, as by consenth
# They dropptd, as by a thundernstroke.  hat might,
#
# orthy Sebastiane  , what mighthSh o more:
# T
# And yet me thinks I see it in thy face,
#
# hat thou shouldst be: the occasion speaks thee, and
#
# y strong imagination sees a crown
#
# ropping upon thy head.
#
# Sm
# ASTIA :
#  hat, art thou waking,
#
# A Tn IA:
#
# o you not hear me speak:
#
# Sm
# ASTIA :
# I don and surely
# It is a sleepy language and thou speakist
#  ut of thy sleep.  hat is it thou didst say
# This is a strange repose, to be asleep
# Tith eyes wide opene standing, speaking, moving,
# And yet so fast asleep.
#
# A Tn IA:
#
# oble Sebastian,
# Thou lethst thy fortune sleeptudie, rathern winkist
# Thile

# %%
plt.plot(losses)

# %%
for c in edf.components:
    if hasattr(c, 'y') and c.y and c.x:
        if c.x.value.shape == (100,) and c.grad.shape == (65,):
            print(c)
            print("x", c.x.value.shape)
            print("y", c.y.value.shape)
            print("del", c.grad.shape)
